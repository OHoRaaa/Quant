# %%
import pyupbit
from pyupbit import Upbit

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('upbit.txt', 'r') as f:
    string = f.readline()
    access = string.strip()
    
    string = f.readline()
    secret = string.strip()

# %%
upbit = Upbit(access, secret)

# %%
# 잔고

# %%
upbit.get_balance('KRW-BTC')
# Out:
# 0.00021794

# %%
upbit.get_balances()
# Out:
# [{'currency': 'KRW',
#   'balance': '133407.25855787',
#   'locked': '0.0',
#   'avg_buy_price': '0',
#   'avg_buy_price_modified': True,
#   'unit_currency': 'KRW'},
#  {'currency': 'BTC',
#   'balance': '0.00021794',
#   'locked': '0.0',
#   'avg_buy_price': '68817000',
#   'avg_buy_price_modified': False,
#   'unit_currency': 'KRW'}]

# %%
for data in upbit.get_balances():
    if float(data['balance']) > 0:
        print(data['currency'], data['balance'])
# Out:
# KRW 133407.25855787
# BTC 0.00021794

# %%
pd.DataFrame(upbit.get_balances())
# Out:
#   currency          balance locked avg_buy_price  avg_buy_price_modified  \
# 0      KRW  133407.25855787    0.0             0                    True
# 1      BTC       0.00021794    0.0      68817000                   False
#
#   unit_currency
# 0           KRW
# 1           KRW

# %%
# 주문

# %%
pyupbit.get_current_price("KRW-XRP")
# Out:
# 785.0

# %%
upbit.buy_limit_order('KRW-XRP', 780, 10)
# Out:
# {'uuid': 'ed9a32b7-2aa7-4096-bde3-d1a952a47c0f',
#  'side': 'bid',
#  'ord_type': 'limit',
#  'price': '780.0',
#  'state': 'wait',
#  'market': 'KRW-XRP',
#  'created_at': '2022-05-04T13:40:01+09:00',
#  'volume': '10.0',
#  'remaining_volume': '10.0',
#  'reserved_fee': '3.9',
#  'remaining_fee': '3.9',
#  'paid_fee': '0.0',
#  'locked': '7803.9',
#  'executed_volume': '0.0',
#  'trades_count': 0}

# %%
upbit.buy_limit_order('KRW-XRP', 790, 10)  # 지정가 주문
# Out:
# {'uuid': '69e8f4bf-b1bb-4560-bac2-e7825db5f6c0',
#  'side': 'bid',
#  'ord_type': 'limit',
#  'price': '790.0',
#  'state': 'wait',
#  'market': 'KRW-XRP',
#  'created_at': '2022-05-04T13:41:07+09:00',
#  'volume': '10.0',
#  'remaining_volume': '10.0',
#  'reserved_fee': '3.95',
#  'remaining_fee': '3.95',
#  'paid_fee': '0.0',
#  'locked': '7903.95',
#  'executed_volume': '0.0',
#  'trades_count': 0}

# %%
pd.DataFrame(upbit.get_balances())
# Out:
#   currency          balance  locked avg_buy_price  avg_buy_price_modified  \
# 0      KRW  117729.42355787  7803.9             0                    True
# 1      BTC       0.00021794     0.0      68817000                   False
# 2      XRP             10.0     0.0           787                   False
#
#   unit_currency
# 0           KRW
# 1           KRW
# 2           KRW

# %%
upbit.sell_limit_order('KRW-XRP', 780, 10)
# Out:
# {'uuid': '74501601-cc0f-4263-9184-3ff8339ccf7c',
#  'side': 'ask',
#  'ord_type': 'limit',
#  'price': '780.0',
#  'state': 'wait',
#  'market': 'KRW-XRP',
#  'created_at': '2022-05-04T13:43:14+09:00',
#  'volume': '10.0',
#  'remaining_volume': '10.0',
#  'reserved_fee': '0.0',
#  'remaining_fee': '0.0',
#  'paid_fee': '0.0',
#  'locked': '10.0',
#  'executed_volume': '0.0',
#  'trades_count': 0}

# %%
pd.DataFrame(upbit.get_balances())
# Out:
#   currency          balance  locked avg_buy_price  avg_buy_price_modified  \
# 0      KRW  125575.49855787  7803.9             0                    True
# 1      BTC       0.00021794     0.0      68817000                   False
#
#   unit_currency
# 0           KRW
# 1           KRW

# %%
# 시장가 주문

# %%
upbit.buy_market_order('KRW-XRP', 10000)     # buy_market_order(종목코드, 매입금액)
# Out:
# {'uuid': '077cc810-5313-40f7-96a3-0b29bcc79bb9',
#  'side': 'bid',
#  'ord_type': 'price',
#  'price': '10000.0',
#  'state': 'wait',
#  'market': 'KRW-XRP',
#  'created_at': '2022-05-04T13:47:01+09:00',
#  'volume': None,
#  'remaining_volume': None,
#  'reserved_fee': '5.0',
#  'remaining_fee': '5.0',
#  'paid_fee': '0.0',
#  'locked': '10005.0',
#  'executed_volume': '0.0',
#  'trades_count': 0}

# %%
balance_df = pd.DataFrame(upbit.get_balances())
balance_df['buy_value'] = balance_df['balance'].astype(float) * balance_df['avg_buy_price'].astype(float)
balance_df
# Out:
#   currency          balance  locked avg_buy_price  avg_buy_price_modified  \
# 0      KRW  115570.49856037  7803.9             0                    True
# 1      BTC       0.00021794     0.0      68817000                   False
# 2      XRP       12.7388535     0.0           785                   False
#
#   unit_currency     buy_value
# 0           KRW      0.000000
# 1           KRW  14997.976980
# 2           KRW   9999.999997

# %%
t_amount = upbit.get_balance('XRP')  # 종목 잔고수량
upbit.sell_market_order('KRW-XRP', t_amount)  # 잔고 수량..
# Out:
# {'uuid': 'e22d468a-080a-4737-aa25-90d360a85dcf',
#  'side': 'ask',
#  'ord_type': 'market',
#  'price': None,
#  'state': 'wait',
#  'market': 'KRW-XRP',
#  'created_at': '2022-05-04T13:54:02+09:00',
#  'volume': '12.7388535',
#  'remaining_volume': '12.7388535',
#  'reserved_fee': '0.0',
#  'remaining_fee': '0.0',
#  'paid_fee': '0.0',
#  'locked': '12.7388535',
#  'executed_volume': '0.0',
#  'trades_count': 0}

# %%
balance_df = pd.DataFrame(upbit.get_balances())
balance_df
# Out:
#   currency         balance  locked avg_buy_price  avg_buy_price_modified  \
# 0      KRW  117688.8360738  7803.9             0                    True
# 1      BTC      0.00021794     0.0      68817000                   False
# 2      XRP            10.0     0.0           786                   False
#
#   unit_currency
# 0           KRW
# 1           KRW
# 2           KRW

# %%
# 주문 내역 확인

# %%
pyupbit.get_current_price("KRW-XRP")
# Out:
# 785.0

# %%
upbit.buy_limit_order('KRW-XRP', 800, 10)
# Out:
# {'uuid': '1cf76bf4-6989-49cd-bf18-9ffef3d59025',
#  'side': 'bid',
#  'ord_type': 'limit',
#  'price': '800.0',
#  'state': 'wait',
#  'market': 'KRW-XRP',
#  'created_at': '2022-05-04T13:56:26+09:00',
#  'volume': '10.0',
#  'remaining_volume': '10.0',
#  'reserved_fee': '4.0',
#  'remaining_fee': '4.0',
#  'paid_fee': '0.0',
#  'locked': '8004.0',
#  'executed_volume': '0.0',
#  'trades_count': 0}

# %%
upbit.get_order('KRW-XRP')
# Out:
# [{'uuid': 'ed9a32b7-2aa7-4096-bde3-d1a952a47c0f',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '780.0',
#   'state': 'wait',
#   'market': 'KRW-XRP',
#   'created_at': '2022-05-04T13:40:01+09:00',
#   'volume': '10.0',
#   'remaining_volume': '10.0',
#   'reserved_fee': '3.9',
#   'remaining_fee': '3.9',
#   'paid_fee': '0.0',
#   'locked': '7803.9',
#   'executed_volume': '0.0',
#   'trades_count': 0}]

# %%
upbit.buy_limit_order('KRW-XRP', 700, 20)
# Out:
# {'uuid': '716ef7a9-5c0a-40e6-abf2-f21c147bcf40',
#  'side': 'bid',
#  'ord_type': 'limit',
#  'price': '700.0',
#  'state': 'wait',
#  'market': 'KRW-XRP',
#  'created_at': '2022-05-04T13:58:00+09:00',
#  'volume': '20.0',
#  'remaining_volume': '20.0',
#  'reserved_fee': '7.0',
#  'remaining_fee': '7.0',
#  'paid_fee': '0.0',
#  'locked': '14007.0',
#  'executed_volume': '0.0',
#  'trades_count': 0}

# %%
r = upbit.get_order('KRW-XRP')

# %%
r[0]['uuid']
# Out:
# '716ef7a9-5c0a-40e6-abf2-f21c147bcf40'

# %%
upbit.cancel_order(r[0]['uuid'])
# Out:
# {'uuid': '716ef7a9-5c0a-40e6-abf2-f21c147bcf40',
#  'side': 'bid',
#  'ord_type': 'limit',
#  'price': '700.0',
#  'state': 'wait',
#  'market': 'KRW-XRP',
#  'created_at': '2022-05-04T13:58:00+09:00',
#  'volume': '20.0',
#  'remaining_volume': '20.0',
#  'reserved_fee': '7.0',
#  'remaining_fee': '7.0',
#  'paid_fee': '0.0',
#  'locked': '14007.0',
#  'executed_volume': '0.0',
#  'trades_count': 0}

# %%
upbit.get_order('KRW-XRP')  # 주문 미체결 내역 목록
# Out:
# [{'uuid': 'ed9a32b7-2aa7-4096-bde3-d1a952a47c0f',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '780.0',
#   'state': 'wait',
#   'market': 'KRW-XRP',
#   'created_at': '2022-05-04T13:40:01+09:00',
#   'volume': '10.0',
#   'remaining_volume': '10.0',
#   'reserved_fee': '3.9',
#   'remaining_fee': '3.9',
#   'paid_fee': '0.0',
#   'locked': '7803.9',
#   'executed_volume': '0.0',
#   'trades_count': 0}]

# %%
# 주문이 정상적으로 체결이되면 내역이 출력되지 않음..

# %%
# 매수주문을 넣고 3초 간 체결이 되지 않으면 취소..

# %%
import time

upbit.buy_limit_order('KRW-XRP', 500, 10)
time.sleep(3)

r = upbit.get_order('KRW-XRP')
if len(r) > 0:
    result = upbit.cancel_order(r[0]['uuid'])
    print(result)
# Out:
# {'uuid': 'd388777c-d160-4b66-bca0-f0fa0e698089', 'side': 'bid', 'ord_type': 'limit', 'price': '500.0', 'state': 'wait', 'market': 'KRW-XRP', 'created_at': '2022-05-04T14:04:55+09:00', 'volume': '10.0', 'remaining_volume': '10.0', 'reserved_fee': '2.5', 'remaining_fee': '2.5', 'paid_fee': '0.0', 'locked': '5002.5', 'executed_volume': '0.0', 'trades_count': 0}

# %%
upbit.cancel_order(r[0]['uuid'])
# Out:
# {'uuid': 'ed9a32b7-2aa7-4096-bde3-d1a952a47c0f',
#  'side': 'bid',
#  'ord_type': 'limit',
#  'price': '780.0',
#  'state': 'wait',
#  'market': 'KRW-XRP',
#  'created_at': '2022-05-04T13:40:01+09:00',
#  'volume': '10.0',
#  'remaining_volume': '10.0',
#  'reserved_fee': '3.9',
#  'remaining_fee': '3.9',
#  'paid_fee': '0.0',
#  'locked': '7803.9',
#  'executed_volume': '0.0',
#  'trades_count': 0}

# %%
r = upbit.get_order('KRW-XRP')
r
# Out:
# []

# %%
upbit.get_order('KRW-XRP', state='wait')  # 미체결 내역
# Out:
# []

# %%
upbit.get_order('KRW-XRP', state='done')  # 체결 내역
# Out:
# [{'uuid': '1cf76bf4-6989-49cd-bf18-9ffef3d59025',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '800.0',
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2022-05-04T13:56:26+09:00',
#   'volume': '10.0',
#   'remaining_volume': '0.0',
#   'reserved_fee': '4.0',
#   'remaining_fee': '0.07',
#   'paid_fee': '3.93',
#   'locked': '140.07',
#   'executed_volume': '10.0',
#   'trades_count': 1},
#  {'uuid': 'e22d468a-080a-4737-aa25-90d360a85dcf',
#   'side': 'ask',
#   'ord_type': 'market',
#   'price': None,
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2022-05-04T13:54:02+09:00',
#   'volume': '12.7388535',
#   'remaining_volume': '0.0',
#   'reserved_fee': '0.0',
#   'remaining_fee': '0.0',
#   'paid_fee': '4.993630572',
#   'locked': '0.0',
#   'executed_volume': '12.7388535',
#   'trades_count': 1},
#  {'uuid': '74501601-cc0f-4263-9184-3ff8339ccf7c',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '780.0',
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2022-05-04T13:43:14+09:00',
#   'volume': '10.0',
#   'remaining_volume': '0.0',
#   'reserved_fee': '0.0',
#   'remaining_fee': '0.0',
#   'paid_fee': '3.925',
#   'locked': '0.0',
#   'executed_volume': '10.0',
#   'trades_count': 1},
#  {'uuid': '69e8f4bf-b1bb-4560-bac2-e7825db5f6c0',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '790.0',
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2022-05-04T13:41:07+09:00',
#   'volume': '10.0',
#   'remaining_volume': '0.0',
#   'reserved_fee': '3.95',
#   'remaining_fee': '0.015',
#   'paid_fee': '3.935',
#   'locked': '30.015',
#   'executed_volume': '10.0',
#   'trades_count': 1},
#  {'uuid': '10b12a84-cdaf-4e5b-8c62-3343353ec261',
#   'side': 'ask',
#   'ord_type': 'market',
#   'price': None,
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T15:43:09+09:00',
#   'volume': '10.0',
#   'remaining_volume': '0.0',
#   'reserved_fee': '0.0',
#   'remaining_fee': '0.0',
#   'paid_fee': '4.55',
#   'locked': '0.0',
#   'executed_volume': '10.0',
#   'trades_count': 1},
#  {'uuid': 'c4f05322-df2e-4186-a637-fec11f4e47d1',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '1000.0',
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T15:40:56+09:00',
#   'volume': '10.0',
#   'remaining_volume': '0.0',
#   'reserved_fee': '5.0',
#   'remaining_fee': '0.44',
#   'paid_fee': '4.56',
#   'locked': '880.44',
#   'executed_volume': '10.0',
#   'trades_count': 1},
#  {'uuid': 'a2ff9e4a-172c-4360-8790-89002b765317',
#   'side': 'ask',
#   'ord_type': 'market',
#   'price': None,
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T15:36:54+09:00',
#   'volume': '75.75336868',
#   'remaining_volume': '0.0',
#   'reserved_fee': '0.0',
#   'remaining_fee': '0.0',
#   'paid_fee': '34.42990606506',
#   'locked': '0.0',
#   'executed_volume': '75.75336868',
#   'trades_count': 1},
#  {'uuid': 'a0961b20-9968-4d93-9d6d-dc6c73090fd1',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '1000.0',
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T15:32:01+09:00',
#   'volume': '10.0',
#   'remaining_volume': '0.0',
#   'reserved_fee': '5.0',
#   'remaining_fee': '0.455',
#   'paid_fee': '4.545',
#   'locked': '910.455',
#   'executed_volume': '10.0',
#   'trades_count': 1},
#  {'uuid': '6a5ded06-e146-454e-80a3-55bac6c57a05',
#   'side': 'ask',
#   'ord_type': 'market',
#   'price': None,
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T13:19:46+09:00',
#   'volume': '10.0',
#   'remaining_volume': '0.0',
#   'reserved_fee': '0.0',
#   'remaining_fee': '0.0',
#   'paid_fee': '4.555',
#   'locked': '0.0',
#   'executed_volume': '10.0',
#   'trades_count': 1},
#  {'uuid': '5bbcdb52-2ee1-4efc-bf1c-ad51fdfabacb',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '1800.0',
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T13:19:17+09:00',
#   'volume': '10.0',
#   'remaining_volume': '0.0',
#   'reserved_fee': '9.0',
#   'remaining_fee': '4.46',
#   'paid_fee': '4.54',
#   'locked': '8924.46',
#   'executed_volume': '10.0',
#   'trades_count': 1},
#  {'uuid': 'e713032a-0dd5-4e22-bf36-d7760cbeab7a',
#   'side': 'ask',
#   'ord_type': 'market',
#   'price': None,
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T13:13:23+09:00',
#   'volume': '140.17984092',
#   'remaining_volume': '0.0',
#   'reserved_fee': '0.0',
#   'remaining_fee': '0.0',
#   'paid_fee': '63.64164777768',
#   'locked': '0.0',
#   'executed_volume': '140.17984092',
#   'trades_count': 1},
#  {'uuid': 'bdeb0c59-7f42-4e3e-b60d-86058c42b24f',
#   'side': 'ask',
#   'ord_type': 'market',
#   'price': None,
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T13:12:33+09:00',
#   'volume': '140.47462835',
#   'remaining_volume': '0.0',
#   'reserved_fee': '0.0',
#   'remaining_fee': '0.0',
#   'paid_fee': '63.7754812709',
#   'locked': '0.0',
#   'executed_volume': '140.47462835',
#   'trades_count': 2},
#  {'uuid': 'a7693bba-af76-456f-9c37-af26dc653dbb',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '600.0',
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T13:09:16+09:00',
#   'volume': '10.0',
#   'remaining_volume': '0.0',
#   'reserved_fee': '0.0',
#   'remaining_fee': '0.0',
#   'paid_fee': '4.55',
#   'locked': '0.0',
#   'executed_volume': '10.0',
#   'trades_count': 1},
#  {'uuid': 'a47c7b51-edf1-45bf-94c4-4e8d30b4c29b',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '1170.0',
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T13:08:48+09:00',
#   'volume': '10.0',
#   'remaining_volume': '0.0',
#   'reserved_fee': '5.85',
#   'remaining_fee': '1.295',
#   'paid_fee': '4.555',
#   'locked': '2591.295',
#   'executed_volume': '10.0',
#   'trades_count': 1},
#  {'uuid': '80bfebff-4eac-4ff3-8a2e-ec6dd21f3163',
#   'side': 'ask',
#   'ord_type': 'market',
#   'price': None,
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2021-12-01T10:58:49+09:00',
#   'volume': '8.0321285',
#   'remaining_volume': '0.0',
#   'reserved_fee': '0.0',
#   'remaining_fee': '0.0',
#   'paid_fee': '4.97991967',
#   'locked': '0.0',
#   'executed_volume': '8.0321285',
#   'trades_count': 1},
#  {'uuid': '8ff72453-5a26-4614-80f6-be25bdfdc83f',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '1000.0',
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2021-12-01T10:49:39+09:00',
#   'volume': '10.0',
#   'remaining_volume': '0.0',
#   'reserved_fee': '0.0',
#   'remaining_fee': '0.0',
#   'paid_fee': '6.2',
#   'locked': '0.0',
#   'executed_volume': '10.0',
#   'trades_count': 1},
#  {'uuid': '6f979a7a-e7f1-45c4-83af-4b1f4beb7d81',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '1500.0',
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2021-12-01T10:47:48+09:00',
#   'volume': '10.0',
#   'remaining_volume': '0.0',
#   'reserved_fee': '7.5',
#   'remaining_fee': '1.275',
#   'paid_fee': '6.225',
#   'locked': '2551.275',
#   'executed_volume': '10.0',
#   'trades_count': 1},
#  {'uuid': '90b4105a-6337-4602-ba28-0ac3860451c7',
#   'side': 'ask',
#   'ord_type': 'market',
#   'price': None,
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2021-11-28T15:14:35+09:00',
#   'volume': '10.0',
#   'remaining_volume': '0.0',
#   'reserved_fee': '0.0',
#   'remaining_fee': '0.0',
#   'paid_fee': '5.825',
#   'locked': '0.0',
#   'executed_volume': '10.0',
#   'trades_count': 1},
#  {'uuid': 'd3ab5c14-de37-4626-aed6-88bff8285826',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '1800.0',
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2021-11-28T15:13:33+09:00',
#   'volume': '10.0',
#   'remaining_volume': '0.0',
#   'reserved_fee': '9.0',
#   'remaining_fee': '3.15',
#   'paid_fee': '5.85',
#   'locked': '6303.15',
#   'executed_volume': '10.0',
#   'trades_count': 1},
#  {'uuid': '01b62b8f-8183-49f1-8bfd-4b5cb170810c',
#   'side': 'ask',
#   'ord_type': 'market',
#   'price': None,
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2021-11-28T15:05:06+09:00',
#   'volume': '78.91552716',
#   'remaining_volume': '0.0',
#   'reserved_fee': '0.0',
#   'remaining_fee': '0.0',
#   'paid_fee': '45.9682945707',
#   'locked': '0.0',
#   'executed_volume': '78.91552716',
#   'trades_count': 1},
#  {'uuid': '583709d2-25dc-4c00-9474-6b32ae88747e',
#   'side': 'ask',
#   'ord_type': 'market',
#   'price': None,
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2021-11-28T15:04:00+09:00',
#   'volume': '36.35432796',
#   'remaining_volume': '0.0',
#   'reserved_fee': '0.0',
#   'remaining_fee': '0.0',
#   'paid_fee': '21.1763960367',
#   'locked': '0.0',
#   'executed_volume': '36.35432796',
#   'trades_count': 1},
#  {'uuid': 'a56bc1f8-242f-4746-acdd-ff8d386150b4',
#   'side': 'ask',
#   'ord_type': 'limit',
#   'price': '600.0',
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2021-11-28T14:51:51+09:00',
#   'volume': '10.0',
#   'remaining_volume': '0.0',
#   'reserved_fee': '0.0',
#   'remaining_fee': '0.0',
#   'paid_fee': '5.825',
#   'locked': '0.0',
#   'executed_volume': '10.0',
#   'trades_count': 1},
#  {'uuid': '3f8273ce-fad9-4dd0-8704-a4ac03246232',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '1170.0',
#   'state': 'done',
#   'market': 'KRW-XRP',
#   'created_at': '2021-11-28T14:50:48+09:00',
#   'volume': '10.0',
#   'remaining_volume': '0.0',
#   'reserved_fee': '5.85',
#   'remaining_fee': '0.0',
#   'paid_fee': '5.85',
#   'locked': '0.0',
#   'executed_volume': '10.0',
#   'trades_count': 1}]

# %%
upbit.get_order('KRW-XRP', state='cancel')   # 주문 취소 내역..
# Out:
# [{'uuid': 'd388777c-d160-4b66-bca0-f0fa0e698089',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '500.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2022-05-04T14:04:55+09:00',
#   'volume': '10.0',
#   'remaining_volume': '10.0',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0.0',
#   'locked': '5002.5',
#   'executed_volume': '0.0',
#   'trades_count': 0},
#  {'uuid': '716ef7a9-5c0a-40e6-abf2-f21c147bcf40',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '700.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2022-05-04T13:58:00+09:00',
#   'volume': '20.0',
#   'remaining_volume': '20.0',
#   'reserved_fee': '7.0',
#   'remaining_fee': '7.0',
#   'paid_fee': '0.0',
#   'locked': '14007.0',
#   'executed_volume': '0.0',
#   'trades_count': 0},
#  {'uuid': '077cc810-5313-40f7-96a3-0b29bcc79bb9',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '10000.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2022-05-04T13:47:01+09:00',
#   'volume': None,
#   'remaining_volume': None,
#   'reserved_fee': '5.0',
#   'remaining_fee': '0.00000000125',
#   'paid_fee': '4.99999999875',
#   'locked': '0.00000250125',
#   'executed_volume': '12.7388535',
#   'trades_count': 1},
#  {'uuid': 'ed9a32b7-2aa7-4096-bde3-d1a952a47c0f',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '780.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2022-05-04T13:40:01+09:00',
#   'volume': '10.0',
#   'remaining_volume': '10.0',
#   'reserved_fee': '3.9',
#   'remaining_fee': '3.9',
#   'paid_fee': '0.0',
#   'locked': '7803.9',
#   'executed_volume': '0.0',
#   'trades_count': 0},
#  {'uuid': 'ef350a80-ae91-403f-a6ad-c84718a40986',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '59638.3054',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T15:34:53+09:00',
#   'volume': None,
#   'remaining_volume': None,
#   'reserved_fee': '29.8191527',
#   'remaining_fee': '0.00000000362',
#   'paid_fee': '29.81915269638',
#   'locked': '0.00000724362',
#   'executed_volume': '65.75336868',
#   'trades_count': 1},
#  {'uuid': 'b78a0c1c-f813-4a5e-b218-a0d74bb217cb',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '500.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T15:30:25+09:00',
#   'volume': '10.0',
#   'remaining_volume': '10.0',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0.0',
#   'locked': '5002.5',
#   'executed_volume': '0.0',
#   'trades_count': 0},
#  {'uuid': 'e94c101a-2cd3-4617-a006-f27d73e5689d',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '500.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T13:20:38+09:00',
#   'volume': '10.0',
#   'remaining_volume': '10.0',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0.0',
#   'locked': '5002.5',
#   'executed_volume': '0.0',
#   'trades_count': 0},
#  {'uuid': '8b94f91f-22c8-44a8-8d7a-f83489a3fea8',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '500.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T13:16:26+09:00',
#   'volume': '10.0',
#   'remaining_volume': '10.0',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0.0',
#   'locked': '5002.5',
#   'executed_volume': '0.0',
#   'trades_count': 0},
#  {'uuid': '1c9142e8-7913-454c-a62c-65dfb5963f2c',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '127423.4754',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T13:13:02+09:00',
#   'volume': None,
#   'remaining_volume': None,
#   'reserved_fee': '63.7117377',
#   'remaining_fee': '0.00000000186',
#   'paid_fee': '63.71173769814',
#   'locked': '0.00000372186',
#   'executed_volume': '140.17984092',
#   'trades_count': 1},
#  {'uuid': '15b6c81b-9c41-4ca6-ba5d-dd3b5718b1be',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '127831.9118',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T13:11:23+09:00',
#   'volume': None,
#   'remaining_volume': None,
#   'reserved_fee': '63.9159559',
#   'remaining_fee': '0.00000000075',
#   'paid_fee': '63.91595589925',
#   'locked': '0.00000150075',
#   'executed_volume': '140.47462835',
#   'trades_count': 1},
#  {'uuid': '62eae60b-552f-44c2-9e4f-bd299d1ac292',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '613.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2022-01-11T13:07:57+09:00',
#   'volume': '10.0',
#   'remaining_volume': '10.0',
#   'reserved_fee': '3.065',
#   'remaining_fee': '3.065',
#   'paid_fee': '0.0',
#   'locked': '6133.065',
#   'executed_volume': '0.0',
#   'trades_count': 0},
#  {'uuid': 'a886d025-5a93-4483-9447-2893a6464a95',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '1000.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2021-12-01T11:11:13+09:00',
#   'volume': '10.0',
#   'remaining_volume': '10.0',
#   'reserved_fee': '5.0',
#   'remaining_fee': '5.0',
#   'paid_fee': '0.0',
#   'locked': '10005.0',
#   'executed_volume': '0.0',
#   'trades_count': 0},
#  {'uuid': '2364337e-2535-4326-9797-7615b48c286f',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '1000.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2021-12-01T11:10:32+09:00',
#   'volume': '10.0',
#   'remaining_volume': '10.0',
#   'reserved_fee': '5.0',
#   'remaining_fee': '5.0',
#   'paid_fee': '0.0',
#   'locked': '10005.0',
#   'executed_volume': '0.0',
#   'trades_count': 0},
#  {'uuid': '96b0a368-ae64-4ce4-bd2f-252c017b0234',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '5000.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2021-12-01T10:58:30+09:00',
#   'volume': None,
#   'remaining_volume': None,
#   'reserved_fee': '2.5',
#   'remaining_fee': '0.000000004375',
#   'paid_fee': '2.499999995625',
#   'locked': '0.000008754375',
#   'executed_volume': '4.01606425',
#   'trades_count': 1},
#  {'uuid': '55263037-8656-49dc-a7b9-6632b7630a77',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '5000.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2021-12-01T10:53:46+09:00',
#   'volume': None,
#   'remaining_volume': None,
#   'reserved_fee': '2.5',
#   'remaining_fee': '0.000000004375',
#   'paid_fee': '2.499999995625',
#   'locked': '0.000008754375',
#   'executed_volume': '4.01606425',
#   'trades_count': 1},
#  {'uuid': '67b88c3f-2640-4417-8c88-3a6d156720a9',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '1000.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2021-12-01T10:46:01+09:00',
#   'volume': '10.0',
#   'remaining_volume': '10.0',
#   'reserved_fee': '5.0',
#   'remaining_fee': '5.0',
#   'paid_fee': '0.0',
#   'locked': '10005.0',
#   'executed_volume': '0.0',
#   'trades_count': 0},
#  {'uuid': 'a715e93e-b37c-4182-be23-ac9df0a5dc42',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '1170.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2021-11-30T10:15:58+09:00',
#   'volume': '10.0',
#   'remaining_volume': '10.0',
#   'reserved_fee': '5.85',
#   'remaining_fee': '5.85',
#   'paid_fee': '0.0',
#   'locked': '11705.85',
#   'executed_volume': '0.0',
#   'trades_count': 0},
#  {'uuid': 'd5c44d94-0564-44d8-9268-d314c460edb3',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '613.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2021-11-30T10:15:41+09:00',
#   'volume': '10.0',
#   'remaining_volume': '10.0',
#   'reserved_fee': '3.065',
#   'remaining_fee': '3.065',
#   'paid_fee': '0.0',
#   'locked': '6133.065',
#   'executed_volume': '0.0',
#   'trades_count': 0},
#  {'uuid': '2f793afa-9c17-4cc1-824f-68988ce0b5b5',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '500.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2021-11-28T15:17:45+09:00',
#   'volume': '10.0',
#   'remaining_volume': '10.0',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0.0',
#   'locked': '5002.5',
#   'executed_volume': '0.0',
#   'trades_count': 0},
#  {'uuid': 'd3a9ac56-eee2-40cf-a693-6808f94631f8',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '500.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2021-11-28T15:10:23+09:00',
#   'volume': '10.0',
#   'remaining_volume': '10.0',
#   'reserved_fee': '2.5',
#   'remaining_fee': '2.5',
#   'paid_fee': '0.0',
#   'locked': '5002.5',
#   'executed_volume': '0.0',
#   'trades_count': 0},
#  {'uuid': 'f272850e-073e-492b-985d-af8896e2c2b0',
#   'side': 'bid',
#   'ord_type': 'price',
#   'price': '134865.7305',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2021-11-28T15:02:09+09:00',
#   'volume': None,
#   'remaining_volume': None,
#   'reserved_fee': '67.43286525',
#   'remaining_fee': '0.0000000048',
#   'paid_fee': '67.4328652452',
#   'locked': '0.0000096048',
#   'executed_volume': '115.26985512',
#   'trades_count': 1},
#  {'uuid': 'bfc15147-1e20-4c6e-8a70-0e9f3abe63ca',
#   'side': 'bid',
#   'ord_type': 'limit',
#   'price': '613.0',
#   'state': 'cancel',
#   'market': 'KRW-XRP',
#   'created_at': '2021-11-28T14:48:39+09:00',
#   'volume': '10.0',
#   'remaining_volume': '10.0',
#   'reserved_fee': '3.065',
#   'remaining_fee': '3.065',
#   'paid_fee': '0.0',
#   'locked': '6133.065',
#   'executed_volume': '0.0',
#   'trades_count': 0}]

# %%
pd.DataFrame(upbit.get_order('KRW-XRP', state='done'))
# Out:
#                                     uuid side ord_type   price state   market  \
# 0   1cf76bf4-6989-49cd-bf18-9ffef3d59025  bid    limit   800.0  done  KRW-XRP
# 1   e22d468a-080a-4737-aa25-90d360a85dcf  ask   market    None  done  KRW-XRP
# 2   74501601-cc0f-4263-9184-3ff8339ccf7c  ask    limit   780.0  done  KRW-XRP
# 3   69e8f4bf-b1bb-4560-bac2-e7825db5f6c0  bid    limit   790.0  done  KRW-XRP
# 4   10b12a84-cdaf-4e5b-8c62-3343353ec261  ask   market    None  done  KRW-XRP
# 5   c4f05322-df2e-4186-a637-fec11f4e47d1  bid    limit  1000.0  done  KRW-XRP
# 6   a2ff9e4a-172c-4360-8790-89002b765317  ask   market    None  done  KRW-XRP
# 7   a0961b20-9968-4d93-9d6d-dc6c73090fd1  bid    limit  1000.0  done  KRW-XRP
# 8   6a5ded06-e146-454e-80a3-55bac6c57a05  ask   market    None  done  KRW-XRP
# 9   5bbcdb52-2ee1-4efc-bf1c-ad51fdfabacb  bid    limit  1800.0  done  KRW-XRP
# 10  e713032a-0dd5-4e22-bf36-d7760cbeab7a  ask   market    None  done  KRW-XRP
# 11  bdeb0c59-7f42-4e3e-b60d-86058c42b24f  ask   market    None  done  KRW-XRP
# 12  a7693bba-af76-456f-9c37-af26dc653dbb  ask    limit   600.0  done  KRW-XRP
# 13  a47c7b51-edf1-45bf-94c4-4e8d30b4c29b  bid    limit  1170.0  done  KRW-XRP
# 14  80bfebff-4eac-4ff3-8a2e-ec6dd21f3163  ask   market    None  done  KRW-XRP
# 15  8ff72453-5a26-4614-80f6-be25bdfdc83f  ask    limit  1000.0  done  KRW-XRP
# 16  6f979a7a-e7f1-45c4-83af-4b1f4beb7d81  bid    limit  1500.0  done  KRW-XRP
# 17  90b4105a-6337-4602-ba28-0ac3860451c7  ask   market    None  done  KRW-XRP
# 18  d3ab5c14-de37-4626-aed6-88bff8285826  bid    limit  1800.0  done  KRW-XRP
# 19  01b62b8f-8183-49f1-8bfd-4b5cb170810c  ask   market    None  done  KRW-XRP
# 20  583709d2-25dc-4c00-9474-6b32ae88747e  ask   market    None  done  KRW-XRP
# 21  a56bc1f8-242f-4746-acdd-ff8d386150b4  ask    limit   600.0  done  KRW-XRP
# 22  3f8273ce-fad9-4dd0-8704-a4ac03246232  bid    limit  1170.0  done  KRW-XRP
#
#                    created_at        volume remaining_volume reserved_fee  \
# 0   2022-05-04T13:56:26+09:00          10.0              0.0          4.0
# 1   2022-05-04T13:54:02+09:00    12.7388535              0.0          0.0
# 2   2022-05-04T13:43:14+09:00          10.0              0.0          0.0
# 3   2022-05-04T13:41:07+09:00          10.0              0.0         3.95
# 4   2022-01-11T15:43:09+09:00          10.0              0.0          0.0
# 5   2022-01-11T15:40:56+09:00          10.0              0.0          5.0
# 6   2022-01-11T15:36:54+09:00   75.75336868              0.0          0.0
# 7   2022-01-11T15:32:01+09:00          10.0              0.0          5.0
# 8   2022-01-11T13:19:46+09:00          10.0              0.0          0.0
# 9   2022-01-11T13:19:17+09:00          10.0              0.0          9.0
# 10  2022-01-11T13:13:23+09:00  140.17984092              0.0          0.0
# 11  2022-01-11T13:12:33+09:00  140.47462835              0.0          0.0
# 12  2022-01-11T13:09:16+09:00          10.0              0.0          0.0
# 13  2022-01-11T13:08:48+09:00          10.0              0.0         5.85
# 14  2021-12-01T10:58:49+09:00     8.0321285              0.0          0.0
# 15  2021-12-01T10:49:39+09:00          10.0              0.0          0.0
# 16  2021-12-01T10:47:48+09:00          10.0              0.0          7.5
# 17  2021-11-28T15:14:35+09:00          10.0              0.0          0.0
# 18  2021-11-28T15:13:33+09:00          10.0              0.0          9.0
# 19  2021-11-28T15:05:06+09:00   78.91552716              0.0          0.0
# 20  2021-11-28T15:04:00+09:00   36.35432796              0.0          0.0
# 21  2021-11-28T14:51:51+09:00          10.0              0.0          0.0
# 22  2021-11-28T14:50:48+09:00          10.0              0.0         5.85
#
#    remaining_fee        paid_fee    locked executed_volume  trades_count
# 0           0.07            3.93    140.07            10.0             1
# 1            0.0     4.993630572       0.0      12.7388535             1
# 2            0.0           3.925       0.0            10.0             1
# 3          0.015           3.935    30.015            10.0             1
# 4            0.0            4.55       0.0            10.0             1
# 5           0.44            4.56    880.44            10.0             1
# 6            0.0  34.42990606506       0.0     75.75336868             1
# 7          0.455           4.545   910.455            10.0             1
# 8            0.0           4.555       0.0            10.0             1
# 9           4.46            4.54   8924.46            10.0             1
# 10           0.0  63.64164777768       0.0    140.17984092             1
# 11           0.0   63.7754812709       0.0    140.47462835             2
# 12           0.0            4.55       0.0            10.0             1
# 13         1.295           4.555  2591.295            10.0             1
# 14           0.0      4.97991967       0.0       8.0321285             1
# 15           0.0             6.2       0.0            10.0             1
# 16         1.275           6.225  2551.275            10.0             1
# 17           0.0           5.825       0.0            10.0             1
# 18          3.15            5.85   6303.15            10.0             1
# 19           0.0   45.9682945707       0.0     78.91552716             1
# 20           0.0   21.1763960367       0.0     36.35432796             1
# 21           0.0           5.825       0.0            10.0             1
# 22           0.0            5.85       0.0            10.0             1
