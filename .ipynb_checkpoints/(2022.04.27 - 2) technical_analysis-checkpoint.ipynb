# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import FinanceDataReader as fdr

# %%
# 이동평균선
# 볼린저벤드
# RSI
# MACD
# (stochstic)

# %%
df = fdr.DataReader('005930', '2020', '2022')

# %%
df.head()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921

# %%
df['Close']/df['Close'].shift(1)-1       # 변화율(수익률)
# Out:
# Date
# 2020-01-02         NaN
# 2020-01-03    0.005435
# 2020-01-06    0.000000
# 2020-01-07    0.005405
# 2020-01-08    0.017921
#                 ...
# 2021-12-24    0.007509
# 2021-12-27   -0.003727
# 2021-12-28    0.001247
# 2021-12-29   -0.018680
# 2021-12-30   -0.006345
# Name: Close, Length: 496, dtype: float64

# %%
df['Close'].pct_change(1)                 # 변화율(수익률)
# Out:
# Date
# 2020-01-02         NaN
# 2020-01-03    0.005435
# 2020-01-06    0.000000
# 2020-01-07    0.005405
# 2020-01-08    0.017921
#                 ...
# 2021-12-24    0.007509
# 2021-12-27   -0.003727
# 2021-12-28    0.001247
# 2021-12-29   -0.018680
# 2021-12-30   -0.006345
# Name: Close, Length: 496, dtype: float64

# %%
df['return'] = df['Change'] + 1                   # 원금대비수익률

# %%
df.head()
# Out:
#              Open   High    Low  Close    Volume    Change    return
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753  0.989247
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435  1.005435
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000  1.000000
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405  1.005405
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921  1.017921

# %%
# 누적 수익률

df['return'].cumprod()
# Out:
# Date
# 2020-01-02    0.989247
# 2020-01-03    0.994624
# 2020-01-06    0.994624
# 2020-01-07    1.000000
# 2020-01-08    1.017921
#                 ...
# 2021-12-24    1.442652
# 2021-12-27    1.437276
# 2021-12-28    1.439068
# 2021-12-29    1.412186
# 2021-12-30    1.403226
# Name: return, Length: 496, dtype: float64

# %%
# 이동평균선

# %%
df.Close
# Out:
# Date
# 2020-01-02    55200
# 2020-01-03    55500
# 2020-01-06    55500
# 2020-01-07    55800
# 2020-01-08    56800
#               ...
# 2021-12-24    80500
# 2021-12-27    80200
# 2021-12-28    80300
# 2021-12-29    78800
# 2021-12-30    78300
# Name: Close, Length: 496, dtype: int64

# %%
df['20ma']= df['Close'].rolling(5).mean()  # 자기를 포함한 3일 이전치 데이터 평균
df['60ma']= df['Close'].rolling(60).mean()

# %%
df
# Out:
#              Open   High    Low  Close    Volume    Change    return      5ma  \
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753  0.989247      NaN
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435  1.005435      NaN
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000  1.000000      NaN
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405  1.005405      NaN
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921  1.017921  55760.0
# ...           ...    ...    ...    ...       ...       ...       ...      ...
# 2021-12-24  80200  80800  80200  80500  12086380  0.007509  1.007509  79000.0
# 2021-12-27  80600  80600  79800  80200  10783368 -0.003727  0.996273  79620.0
# 2021-12-28  80200  80400  79700  80300  18226325  0.001247  1.001247  80060.0
# 2021-12-29  80200  80200  78500  78800  19794795 -0.018680  0.981320  79940.0
# 2021-12-30  78900  79500  78100  78300  14236700 -0.006345  0.993655  79620.0
#
#                20ma          60ma
# Date
# 2020-01-02      NaN           NaN
# 2020-01-03      NaN           NaN
# 2020-01-06      NaN           NaN
# 2020-01-07      NaN           NaN
# 2020-01-08  55760.0           NaN
# ...             ...           ...
# 2021-12-24  79000.0  73046.666667
# 2021-12-27  79620.0  73148.333333
# 2021-12-28  80060.0  73266.666667
# 2021-12-29  79940.0  73376.666667
# 2021-12-30  79620.0  73493.333333
#
# [496 rows x 10 columns]

# %%
df[['Close', '20ma', '60ma']].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# 지수 이동평균선: 현재와 가까운 값에 더 큰 가중치를 주어서 계산한 평균값

# %%
df['20ewma']= df['Close'].ewm(span=20).mean()
df['60ewma']= df['Close'].ewm(span=60).mean()

# %%
df[['Close', '20ewma', '60ewma']].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close
# Out:
# Date
# 2020-01-02    55200
# 2020-01-03    55500
# 2020-01-06    55500
# 2020-01-07    55800
# 2020-01-08    56800
#               ...
# 2021-12-24    80500
# 2021-12-27    80200
# 2021-12-28    80300
# 2021-12-29    78800
# 2021-12-30    78300
# Name: Close, Length: 496, dtype: int64

# %%
df['Close'].asfreq('3D')
# Out:
# Date
# 2020-01-02    55200.0
# 2020-01-05        NaN
# 2020-01-08    56800.0
# 2020-01-11        NaN
# 2020-01-14    60000.0
#                ...
# 2021-12-16    77800.0
# 2021-12-19        NaN
# 2021-12-22    79400.0
# 2021-12-25        NaN
# 2021-12-28    80300.0
# Freq: 3D, Name: Close, Length: 243, dtype: float64

# %%
df['Close'].resample('M').mean()      # 월평균
# Out:
# Date
# 2020-01-31    58815.000000
# 2020-02-29    59085.000000
# 2020-03-31    50168.181818
# 2020-04-30    49045.000000
# 2020-05-31    49100.000000
# 2020-06-30    52986.363636
# 2020-07-31    54726.086957
# 2020-08-31    56980.000000
# 2020-09-30    58176.190476
# 2020-10-31    59736.842105
# 2020-11-30    63419.047619
# 2020-12-31    73619.047619
# 2021-01-31    86565.000000
# 2021-02-28    83127.777778
# 2021-03-31    82072.727273
# 2021-04-30    83586.363636
# 2021-05-31    80521.052632
# 2021-06-30    81104.545455
# 2021-07-31    79577.272727
# 2021-08-31    77023.809524
# 2021-09-30    76305.263158
# 2021-10-31    70563.157895
# 2021-11-30    71536.363636
# 2021-12-31    77809.090909
# Freq: M, Name: Close, dtype: float64

# %%
df['Close'].resample('Q').mean()      # 분기평균
# Out:
# Date
# 2020-03-31    55833.870968
# 2020-06-30    50483.606557
# 2020-09-30    56562.500000
# 2020-12-31    65783.606557
# 2021-03-31    83886.666667
# 2021-06-30    81795.238095
# 2021-09-30    77709.677419
# 2021-12-31    73433.333333
# Freq: Q-DEC, Name: Close, dtype: float64

# %%
df['Close'].resample('W').mean()      # 주평균
# Out:
# Date
# 2020-01-05    55350.0
# 2020-01-12    57240.0
# 2020-01-19    60200.0
# 2020-01-26    61725.0
# 2020-02-02    57875.0
#                ...
# 2021-12-05    73880.0
# 2021-12-12    77240.0
# 2021-12-19    77440.0
# 2021-12-26    79000.0
# 2022-01-02    79400.0
# Freq: W-SUN, Name: Close, Length: 105, dtype: float64

# %%
# bollinger band

# %%
df = fdr.DataReader('005930', '2020', '2023')

# %%
df.tail()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2022-04-21  67600  68300  67500  67700  12847448  0.004451
# 2022-04-22  67200  67300  66700  67000  11791478 -0.010340
# 2022-04-25  66500  66700  66300  66300  11016474 -0.010448
# 2022-04-26  66400  66700  66100  66100  12946923 -0.003017
# 2022-04-27  65400  65500  64900  65100  10800158 -0.015129

# %%
df['ma20'] = df['Close'].rolling(20).mean()

# %%
df.head()
# Out:
#              Open   High    Low  Close    Volume    Change  ma20
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753   NaN
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435   NaN
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000   NaN
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405   NaN
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921   NaN

# %%
plt.hist(df.Change, bins=100)
plt.show()

# %%
plt.hist((df.Change - df.Change.mean())/df.Change.std(), bins=100)
plt.show()

# %%
# 표준정규분포 : 평균이 0이고, 표준편차가 1인 좌우대칭인 정규분포
# 표준편차 : 데이터들의 평균과의 차이(편차)의 평균, 데이터가 평균에서 얼마나 떨어져 있는가
# 정규분포의 성질
#  1. 평균에서 +- 1 표준편차의 범위에 68.2%의 데이터가 존재
#  2. 평균에서 +- 2 표준편차의 범위에 95%의 데이터가 존재
#  3. 평균에서 +- 3 표준편차의 범위에 99.7%의 데이터가 존재

# %%
df['stddev']=df['Close'].rolling(20).std() # 20일 이동 표준편차

# %%
df.head()
# Out:
#              Open   High    Low  Close    Volume    Change  ma20  stddev
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753   NaN     NaN
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435   NaN     NaN
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000   NaN     NaN
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405   NaN     NaN
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921   NaN     NaN

# %%
df['upper_b'] = df['ma20'] + (df['stddev']*2)
df['lower_b'] = df['ma20'] - (df['stddev']*2)

# %%
df
# Out:
#              Open   High    Low  Close    Volume    Change     ma20  \
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753      NaN
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435      NaN
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000      NaN
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405      NaN
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921      NaN
# ...           ...    ...    ...    ...       ...       ...      ...
# 2022-04-21  67600  68300  67500  67700  12847448  0.004451  68395.0
# 2022-04-22  67200  67300  66700  67000  11791478 -0.010340  68255.0
# 2022-04-25  66500  66700  66300  66300  11016474 -0.010448  68085.0
# 2022-04-26  66400  66700  66100  66100  12946923 -0.003017  67880.0
# 2022-04-27  65400  65500  64900  65100  10800158 -0.015129  67640.0
#
#                  stddev       upper_b       lower_b
# Date
# 2020-01-02          NaN           NaN           NaN
# 2020-01-03          NaN           NaN           NaN
# 2020-01-06          NaN           NaN           NaN
# 2020-01-07          NaN           NaN           NaN
# 2020-01-08          NaN           NaN           NaN
# ...                 ...           ...           ...
# 2022-04-21  1146.837758  70688.675515  66101.324485
# 2022-04-22  1137.159434  70529.318869  65980.681131
# 2022-04-25  1163.603749  70412.207498  65757.792502
# 2022-04-26  1132.114928  70144.229856  65615.770144
# 2022-04-27  1188.718904  70017.437807  65262.562193
#
# [574 rows x 10 columns]

# %%
df[['upper_b', 'lower_b', 'ma20', 'Close']].plot(figsize=(15,5))
plt.fill_between(df.index, df.lower_b, df.upper_b, alpha=0.2)

# %%
# 매수 : lower_b 아래에 주가가 있는 경우

# %%
df['pos1'] = df['Close'] <= df['lower_b']

# %%
df['pos1'] = df.pos.apply(int)

# %%
df['20ma_upper']=df['Close'] >= df['ma20']

# %%
df['20ma_upper']= df['20ma_upper'].apply(int)

# %%
df.drop(['Open', 'High', 'Low', 'Volume', 'Change'], axis = 1, inplace=True)

# %%
df
# Out:
#             Close     ma20       stddev       upper_b       lower_b  pos  \
# Date
# 2020-01-02  55200      NaN          NaN           NaN           NaN    0
# 2020-01-03  55500      NaN          NaN           NaN           NaN    0
# 2020-01-06  55500      NaN          NaN           NaN           NaN    0
# 2020-01-07  55800      NaN          NaN           NaN           NaN    0
# 2020-01-08  56800      NaN          NaN           NaN           NaN    0
# ...           ...      ...          ...           ...           ...  ...
# 2022-04-21  67700  68395.0  1146.837758  70688.675515  66101.324485    0
# 2022-04-22  67000  68255.0  1137.159434  70529.318869  65980.681131    0
# 2022-04-25  66300  68085.0  1163.603749  70412.207498  65757.792502    0
# 2022-04-26  66100  67880.0  1132.114928  70144.229856  65615.770144    0
# 2022-04-27  65100  67640.0  1188.718904  70017.437807  65262.562193    1
#
#             pos1  20ma_upper
# Date
# 2020-01-02     0           0
# 2020-01-03     0           0
# 2020-01-06     0           0
# 2020-01-07     0           0
# 2020-01-08     0           0
# ...          ...         ...
# 2022-04-21     0           0
# 2022-04-22     0           0
# 2022-04-25     0           0
# 2022-04-26     0           0
# 2022-04-27     1           0
#
# [574 rows x 8 columns]

# %%
# 매도 : 주가가 20ma를 dead cross

# %%
df.head(3)
# Out:
#             Close  ma20  stddev  upper_b  lower_b  pos  pos1  20ma_upper
# Date
# 2020-01-02  55200   NaN     NaN      NaN      NaN    0     0           0
# 2020-01-03  55500   NaN     NaN      NaN      NaN    0     0           0
# 2020-01-06  55500   NaN     NaN      NaN      NaN    0     0           0

# %%
df['sell_sig'] = (df['20ma_upper'].shift(1) == 1) & (df['Close'] < df['ma20'])
df['sell_sig'] = df['sell_sig'].apply(int)

# %%
df.head()
# Out:
#             Close  ma20  stddev  upper_b  lower_b  pos  pos1  20ma_upper  \
# Date
# 2020-01-02  55200   NaN     NaN      NaN      NaN    0     0           0
# 2020-01-03  55500   NaN     NaN      NaN      NaN    0     0           0
# 2020-01-06  55500   NaN     NaN      NaN      NaN    0     0           0
# 2020-01-07  55800   NaN     NaN      NaN      NaN    0     0           0
# 2020-01-08  56800   NaN     NaN      NaN      NaN    0     0           0
#
#             sell_sig
# Date
# 2020-01-02         0
# 2020-01-03         0
# 2020-01-06         0
# 2020-01-07         0
# 2020-01-08         0

# %%
buy_df = df[df['pos1'] == 1]

# %%
sell_df = df[df['sell_sig'] == 1]

# %%
concat_df = pd.concat([buy_df, sell_df]).sort_index()
concat_df = concat_df.loc['2020-02-28':]

# %%
concat_df
# Out:
#             Close     ma20       stddev       upper_b       lower_b  pos  \
# Date
# 2020-02-28  54200  59085.0  2030.368128  63145.736257  55024.263743    1
# 2020-03-12  50800  56880.0  2980.038855  62840.077711  50919.922289    1
# 2020-03-13  49950  56287.5  3124.852628  62537.205256  50037.794744    1
# 2020-03-16  48900  55657.5  3284.704385  62226.908769  49088.091231    1
# 2020-03-17  47300  55032.5  3626.447987  62285.395973  47779.604027    1
# ...           ...      ...          ...           ...           ...  ...
# 2022-04-07  68000  69790.0   740.483484  71270.966967  68309.033033    1
# 2022-04-08  67800  69680.0   861.210898  71402.421796  67957.578204    1
# 2022-04-12  67000  69440.0  1099.952152  71639.904304  67240.095696    1
# 2022-04-15  66600  68965.0  1152.697066  71270.394132  66659.605868    1
# 2022-04-27  65100  67640.0  1188.718904  70017.437807  65262.562193    1
#
#             pos1  20ma_upper  sell_sig
# Date
# 2020-02-28     1           0         0
# 2020-03-12     1           0         0
# 2020-03-13     1           0         0
# 2020-03-16     1           0         0
# 2020-03-17     1           0         0
# ...          ...         ...       ...
# 2022-04-07     1           0         0
# 2022-04-08     1           0         0
# 2022-04-12     1           0         0
# 2022-04-15     1           0         0
# 2022-04-27     1           0         0
#
# [68 rows x 9 columns]

# %%
buy_df = buy_df.loc['2020-02-28':]

# %%
sell_df = sell_df.loc['2020-02-28':]

# %%
buy_df.index
# Out:
# DatetimeIndex(['2020-02-28', '2020-03-12', '2020-03-13', '2020-03-16',
#                '2020-03-17', '2020-03-18', '2020-03-19', '2020-08-31',
#                '2020-10-30', '2021-05-12', '2021-05-13', '2021-08-13',
#                '2021-08-17', '2021-09-29', '2021-09-30', '2021-10-01',
#                '2021-10-05', '2021-10-06', '2021-10-12', '2022-01-25',
#                '2022-01-26', '2022-01-27', '2022-02-24', '2022-03-07',
#                '2022-03-08', '2022-04-06', '2022-04-07', '2022-04-08',
#                '2022-04-12', '2022-04-15', '2022-04-27'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
sell_df.index
# Out:
# DatetimeIndex(['2020-05-04', '2020-05-22', '2020-06-15', '2020-06-22',
#                '2020-06-25', '2020-06-29', '2020-08-20', '2020-09-24',
#                '2020-09-29', '2020-10-28', '2021-01-27', '2021-02-17',
#                '2021-02-26', '2021-03-04', '2021-03-15', '2021-03-17',
#                '2021-03-19', '2021-03-31', '2021-04-19', '2021-04-21',
#                '2021-05-11', '2021-06-14', '2021-06-18', '2021-06-29',
#                '2021-07-08', '2021-07-16', '2021-08-11', '2021-09-02',
#                '2021-09-28', '2021-11-05', '2021-11-10', '2021-11-18',
#                '2021-11-30', '2022-01-05', '2022-01-13', '2022-02-11',
#                '2022-02-22'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
concat_df = pd.concat([buy_df, sell_df]).sort_index()
concat_df.head()
# Out:
#             Close     ma20       stddev       upper_b       lower_b  pos  \
# Date
# 2020-02-28  54200  59085.0  2030.368128  63145.736257  55024.263743    1
# 2020-03-12  50800  56880.0  2980.038855  62840.077711  50919.922289    1
# 2020-03-13  49950  56287.5  3124.852628  62537.205256  50037.794744    1
# 2020-03-16  48900  55657.5  3284.704385  62226.908769  49088.091231    1
# 2020-03-17  47300  55032.5  3626.447987  62285.395973  47779.604027    1
#
#             pos1  20ma_upper  sell_sig
# Date
# 2020-02-28     1           0         0
# 2020-03-12     1           0         0
# 2020-03-13     1           0         0
# 2020-03-16     1           0         0
# 2020-03-17     1           0         0

# %%
concat_df['st_pos'] = concat_df['pos1'] - concat_df['sell_sig']

# %%
concat_df
# Out:
#             Close     ma20       stddev       upper_b       lower_b  pos  \
# Date
# 2020-02-28  54200  59085.0  2030.368128  63145.736257  55024.263743    1
# 2020-03-12  50800  56880.0  2980.038855  62840.077711  50919.922289    1
# 2020-03-13  49950  56287.5  3124.852628  62537.205256  50037.794744    1
# 2020-03-16  48900  55657.5  3284.704385  62226.908769  49088.091231    1
# 2020-03-17  47300  55032.5  3626.447987  62285.395973  47779.604027    1
# ...           ...      ...          ...           ...           ...  ...
# 2022-04-07  68000  69790.0   740.483484  71270.966967  68309.033033    1
# 2022-04-08  67800  69680.0   861.210898  71402.421796  67957.578204    1
# 2022-04-12  67000  69440.0  1099.952152  71639.904304  67240.095696    1
# 2022-04-15  66600  68965.0  1152.697066  71270.394132  66659.605868    1
# 2022-04-27  65100  67640.0  1188.718904  70017.437807  65262.562193    1
#
#             pos1  20ma_upper  sell_sig  st_pos
# Date
# 2020-02-28     1           0         0       1
# 2020-03-12     1           0         0       1
# 2020-03-13     1           0         0       1
# 2020-03-16     1           0         0       1
# 2020-03-17     1           0         0       1
# ...          ...         ...       ...     ...
# 2022-04-07     1           0         0       1
# 2022-04-08     1           0         0       1
# 2022-04-12     1           0         0       1
# 2022-04-15     1           0         0       1
# 2022-04-27     1           0         0       1
#
# [68 rows x 10 columns]

# %%
concat_df['st_pos'].value_counts()
# Out:
# -1    37
#  1    31
# Name: st_pos, dtype: int64

# %%
df['RSI'] df['AU'].(df['AU'] + df['AD'])

# %%
df['Close'].plot()
df[['RSI', 'RSI_sig']].plot(figsize=(15,5))
plt.axhline(0.7, c='y', ls='--')
plt.axhline(0.3, c='y', ls='--')

# %%
# MACD

# 단기이평(12) - 장기이평(26)
# Macd signal : macd 9ma

# %%
df = fdr.DataReader('005930', '2020', '2023')
df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921
# ...           ...    ...    ...    ...       ...       ...
# 2022-04-21  67600  68300  67500  67700  12847448  0.004451
# 2022-04-22  67200  67300  66700  67000  11791478 -0.010340
# 2022-04-25  66500  66700  66300  66300  11016474 -0.010448
# 2022-04-26  66400  66700  66100  66100  12946923 -0.003017
# 2022-04-27  65400  65500  64900  65100  15334757 -0.015129
#
# [574 rows x 6 columns]

# %%
df['ema_short'] = df['Close'].ewm(12).mean()
df['ema_long'] = df['Close'].ewm(12).mean()

# %%
df[['Close', 'ema_short', 'ema_long']].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df['macd'] = df['ema_short'] - df['ema_long']
df['macd_signal'] = df['macd'].ewm(9).mean()
df['macdhist'] = df['macd'] - df['macd_signal']

# %%
df[['macd', 'macd_signal', 'macdhist']]
# Out:
#             macd  macd_signal  macdhist
# Date
# 2020-01-02   0.0          0.0       0.0
# 2020-01-03   0.0          0.0       0.0
# 2020-01-06   0.0          0.0       0.0
# 2020-01-07   0.0          0.0       0.0
# 2020-01-08   0.0          0.0       0.0
# ...          ...          ...       ...
# 2022-04-21   0.0          0.0       0.0
# 2022-04-22   0.0          0.0       0.0
# 2022-04-25   0.0          0.0       0.0
# 2022-04-26   0.0          0.0       0.0
# 2022-04-27   0.0          0.0       0.0
#
# [574 rows x 3 columns]
