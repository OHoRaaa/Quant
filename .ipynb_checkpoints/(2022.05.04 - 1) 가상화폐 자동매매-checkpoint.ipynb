# %%
# upbit, bithumb

# %%
# !pip install -U pyupbit

# %%
# upbit API

# %%
import pyupbit

# %%
tickers = pyupbit.get_tickers()
print(tickers)
# Out:
# ['KRW-BTC', 'KRW-ETH', 'BTC-ETH', 'BTC-LTC', 'BTC-XRP', 'BTC-ETC', 'BTC-OMG', 'BTC-CVC', 'BTC-DGB', 'BTC-SC', 'BTC-SNT', 'BTC-WAVES', 'BTC-NMR', 'BTC-XEM', 'BTC-QTUM', 'BTC-BAT', 'BTC-LSK', 'BTC-STEEM', 'BTC-DOGE', 'BTC-BNT', 'BTC-XLM', 'BTC-ARDR', 'BTC-ARK', 'BTC-STORJ', 'BTC-GRS', 'BTC-REP', 'BTC-RLC', 'USDT-BTC', 'USDT-ETH', 'USDT-LTC', 'USDT-XRP', 'USDT-ETC', 'KRW-NEO', 'KRW-MTL', 'KRW-LTC', 'KRW-XRP', 'KRW-ETC', 'KRW-OMG', 'KRW-SNT', 'KRW-WAVES', 'KRW-XEM', 'KRW-QTUM', 'KRW-LSK', 'KRW-STEEM', 'KRW-XLM', 'KRW-ARDR', 'KRW-ARK', 'KRW-STORJ', 'KRW-GRS', 'KRW-REP', 'KRW-ADA', 'BTC-ADA', 'BTC-MANA', 'USDT-OMG', 'KRW-SBD', 'BTC-SBD', 'KRW-POWR', 'BTC-POWR', 'KRW-BTG', 'USDT-ADA', 'BTC-DNT', 'BTC-ZRX', 'BTC-TRX', 'BTC-TUSD', 'BTC-LRC', 'KRW-ICX', 'KRW-EOS', 'USDT-TUSD', 'KRW-TRX', 'BTC-POLY', 'USDT-SC', 'USDT-TRX', 'KRW-SC', 'KRW-ONT', 'KRW-ZIL', 'KRW-POLY', 'KRW-ZRX', 'KRW-LOOM', 'BTC-BCH', 'USDT-BCH', 'KRW-BCH', 'BTC-MFT', 'BTC-LOOM', 'KRW-BAT', 'KRW-IOST', 'BTC-RFR', 'KRW-RFR', 'USDT-DGB', 'KRW-CVC', 'KRW-IQ', 'KRW-IOTA', 'BTC-RVN', 'BTC-GO', 'BTC-UPP', 'BTC-ENJ', 'KRW-MFT', 'KRW-ONG', 'KRW-GAS', 'BTC-MTL', 'KRW-UPP', 'KRW-ELF', 'USDT-DOGE', 'USDT-ZRX', 'USDT-RVN', 'USDT-BAT', 'KRW-KNC', 'BTC-MOC', 'BTC-ZIL', 'KRW-BSV', 'BTC-BSV', 'BTC-IOST', 'KRW-THETA', 'BTC-DENT', 'KRW-QKC', 'BTC-ELF', 'KRW-BTT', 'BTC-IOTX', 'BTC-SOLVE', 'BTC-NKN', 'BTC-META', 'KRW-MOC', 'BTC-ANKR', 'BTC-CRO', 'KRW-ENJ', 'KRW-TFUEL', 'KRW-MANA', 'KRW-ANKR', 'BTC-ORBS', 'BTC-AERGO', 'KRW-AERGO', 'KRW-ATOM', 'KRW-TT', 'KRW-CRE', 'BTC-ATOM', 'BTC-STPT', 'KRW-MBL', 'BTC-EOS', 'BTC-LUNA', 'BTC-DAI', 'BTC-MKR', 'BTC-BORA', 'KRW-WAXP', 'BTC-WAXP', 'KRW-HBAR', 'KRW-MED', 'BTC-MED', 'BTC-MLK', 'KRW-MLK', 'KRW-STPT', 'BTC-VET', 'KRW-ORBS', 'BTC-CHZ', 'KRW-VET', 'BTC-FX', 'BTC-OGN', 'KRW-CHZ', 'BTC-XTZ', 'BTC-HIVE', 'BTC-HBD', 'BTC-OBSR', 'BTC-DKA', 'KRW-STMX', 'BTC-STMX', 'BTC-AHT', 'BTC-PCI', 'KRW-DKA', 'BTC-LINK', 'KRW-HIVE', 'KRW-KAVA', 'BTC-KAVA', 'KRW-AHT', 'KRW-LINK', 'KRW-XTZ', 'KRW-BORA', 'BTC-JST', 'BTC-CHR', 'BTC-DAD', 'BTC-TON', 'KRW-JST', 'BTC-CTSI', 'BTC-DOT', 'KRW-CRO', 'BTC-COMP', 'BTC-SXP', 'BTC-HUNT', 'KRW-TON', 'BTC-ONIT', 'BTC-CRV', 'BTC-ALGO', 'BTC-RSR', 'KRW-SXP', 'BTC-OXT', 'BTC-PLA', 'KRW-HUNT', 'BTC-MARO', 'BTC-SAND', 'BTC-SUN', 'KRW-PLA', 'KRW-DOT', 'BTC-SRM', 'BTC-QTCON', 'BTC-MVL', 'KRW-SRM', 'KRW-MVL', 'BTC-REI', 'BTC-AQT', 'BTC-AXS', 'BTC-STRAX', 'KRW-STRAX', 'KRW-AQT', 'BTC-GLM', 'KRW-GLM', 'BTC-FCT2', 'BTC-SSX', 'KRW-SSX', 'KRW-META', 'KRW-FCT2', 'BTC-FIL', 'BTC-UNI', 'BTC-BASIC', 'BTC-INJ', 'BTC-PROM', 'BTC-VAL', 'BTC-PSG', 'BTC-JUV', 'BTC-CBK', 'BTC-FOR', 'KRW-CBK', 'BTC-BFC', 'BTC-LINA', 'BTC-HUM', 'BTC-CELO', 'KRW-SAND', 'KRW-HUM', 'BTC-IQ', 'BTC-STX', 'KRW-DOGE', 'BTC-NEAR', 'BTC-AUCTION', 'BTC-DAWN', 'BTC-FLOW', 'BTC-STRK', 'KRW-STRK', 'BTC-PUNDIX', 'KRW-PUNDIX', 'KRW-FLOW', 'KRW-DAWN', 'KRW-AXS', 'KRW-STX', 'BTC-GRT', 'BTC-SNX', 'BTC-USDP', 'KRW-XEC', 'KRW-SOL', 'BTC-SOL', 'KRW-MATIC', 'BTC-MATIC', 'KRW-NU', 'BTC-NU', 'KRW-AAVE', 'KRW-1INCH', 'BTC-AAVE', 'BTC-1INCH', 'BTC-MASK', 'KRW-ALGO', 'BTC-AUDIO', 'KRW-NEAR', 'BTC-YGG', 'BTC-GTC', 'BTC-OCEAN', 'BTC-CTC', 'BTC-LPT', 'KRW-WEMIX', 'BTC-WEMIX', 'KRW-AVAX', 'BTC-AVAX', 'BTC-IMX', 'BTC-RNDR', 'BTC-RLY', 'KRW-T', 'BTC-T', 'KRW-CELO', 'BTC-RAD', 'BTC-AGLD', 'BTC-API3', 'BTC-ARPA', 'BTC-ENS']

# %%
for 변수 in tickers:
    print(변수)
# Out:
# KRW-BTC
# KRW-ETH
# BTC-ETH
# BTC-LTC
# BTC-XRP
# BTC-ETC
# BTC-OMG
# BTC-CVC
# BTC-DGB
# BTC-SC
# BTC-SNT
# BTC-WAVES
# BTC-NMR
# BTC-XEM
# BTC-QTUM
# BTC-BAT
# BTC-LSK
# BTC-STEEM
# BTC-DOGE
# BTC-BNT
# BTC-XLM
# BTC-ARDR
# BTC-ARK
# BTC-STORJ
# BTC-GRS
# BTC-REP
# BTC-RLC
# USDT-BTC
# USDT-ETH
# USDT-LTC
# USDT-XRP
# USDT-ETC
# KRW-NEO
# KRW-MTL
# KRW-LTC
# KRW-XRP
# KRW-ETC
# KRW-OMG
# KRW-SNT
# KRW-WAVES
# KRW-XEM
# KRW-QTUM
# KRW-LSK
# KRW-STEEM
# KRW-XLM
# KRW-ARDR
# KRW-ARK
# KRW-STORJ
# KRW-GRS
# KRW-REP
# KRW-ADA
# BTC-ADA
# BTC-MANA
# USDT-OMG
# KRW-SBD
# BTC-SBD
# KRW-POWR
# BTC-POWR
# KRW-BTG
# USDT-ADA
# BTC-DNT
# BTC-ZRX
# BTC-TRX
# BTC-TUSD
# BTC-LRC
# KRW-ICX
# KRW-EOS
# USDT-TUSD
# KRW-TRX
# BTC-POLY
# USDT-SC
# USDT-TRX
# KRW-SC
# KRW-ONT
# KRW-ZIL
# KRW-POLY
# KRW-ZRX
# KRW-LOOM
# BTC-BCH
# USDT-BCH
# KRW-BCH
# BTC-MFT
# BTC-LOOM
# KRW-BAT
# KRW-IOST
# BTC-RFR
# KRW-RFR
# USDT-DGB
# KRW-CVC
# KRW-IQ
# KRW-IOTA
# BTC-RVN
# BTC-GO
# BTC-UPP
# BTC-ENJ
# KRW-MFT
# KRW-ONG
# KRW-GAS
# BTC-MTL
# KRW-UPP
# KRW-ELF
# USDT-DOGE
# USDT-ZRX
# USDT-RVN
# USDT-BAT
# KRW-KNC
# BTC-MOC
# BTC-ZIL
# KRW-BSV
# BTC-BSV
# BTC-IOST
# KRW-THETA
# BTC-DENT
# KRW-QKC
# BTC-ELF
# KRW-BTT
# BTC-IOTX
# BTC-SOLVE
# BTC-NKN
# BTC-META
# KRW-MOC
# BTC-ANKR
# BTC-CRO
# KRW-ENJ
# KRW-TFUEL
# KRW-MANA
# KRW-ANKR
# BTC-ORBS
# BTC-AERGO
# KRW-AERGO
# KRW-ATOM
# KRW-TT
# KRW-CRE
# BTC-ATOM
# BTC-STPT
# KRW-MBL
# BTC-EOS
# BTC-LUNA
# BTC-DAI
# BTC-MKR
# BTC-BORA
# KRW-WAXP
# BTC-WAXP
# KRW-HBAR
# KRW-MED
# BTC-MED
# BTC-MLK
# KRW-MLK
# KRW-STPT
# BTC-VET
# KRW-ORBS
# BTC-CHZ
# KRW-VET
# BTC-FX
# BTC-OGN
# KRW-CHZ
# BTC-XTZ
# BTC-HIVE
# BTC-HBD
# BTC-OBSR
# BTC-DKA
# KRW-STMX
# BTC-STMX
# BTC-AHT
# BTC-PCI
# KRW-DKA
# BTC-LINK
# KRW-HIVE
# KRW-KAVA
# BTC-KAVA
# KRW-AHT
# KRW-LINK
# KRW-XTZ
# KRW-BORA
# BTC-JST
# BTC-CHR
# BTC-DAD
# BTC-TON
# KRW-JST
# BTC-CTSI
# BTC-DOT
# KRW-CRO
# BTC-COMP
# BTC-SXP
# BTC-HUNT
# KRW-TON
# BTC-ONIT
# BTC-CRV
# BTC-ALGO
# BTC-RSR
# KRW-SXP
# BTC-OXT
# BTC-PLA
# KRW-HUNT
# BTC-MARO
# BTC-SAND
# BTC-SUN
# KRW-PLA
# KRW-DOT
# BTC-SRM
# BTC-QTCON
# BTC-MVL
# KRW-SRM
# KRW-MVL
# BTC-REI
# BTC-AQT
# BTC-AXS
# BTC-STRAX
# KRW-STRAX
# KRW-AQT
# BTC-GLM
# KRW-GLM
# BTC-FCT2
# BTC-SSX
# KRW-SSX
# KRW-META
# KRW-FCT2
# BTC-FIL
# BTC-UNI
# BTC-BASIC
# BTC-INJ
# BTC-PROM
# BTC-VAL
# BTC-PSG
# BTC-JUV
# BTC-CBK
# BTC-FOR
# KRW-CBK
# BTC-BFC
# BTC-LINA
# BTC-HUM
# BTC-CELO
# KRW-SAND
# KRW-HUM
# BTC-IQ
# BTC-STX
# KRW-DOGE
# BTC-NEAR
# BTC-AUCTION
# BTC-DAWN
# BTC-FLOW
# BTC-STRK
# KRW-STRK
# BTC-PUNDIX
# KRW-PUNDIX
# KRW-FLOW
# KRW-DAWN
# KRW-AXS
# KRW-STX
# BTC-GRT
# BTC-SNX
# BTC-USDP
# KRW-XEC
# KRW-SOL
# BTC-SOL
# KRW-MATIC
# BTC-MATIC
# KRW-NU
# BTC-NU
# KRW-AAVE
# KRW-1INCH
# BTC-AAVE
# BTC-1INCH
# BTC-MASK
# KRW-ALGO
# BTC-AUDIO
# KRW-NEAR
# BTC-YGG
# BTC-GTC
# BTC-OCEAN
# BTC-CTC
# BTC-LPT
# KRW-WEMIX
# BTC-WEMIX
# KRW-AVAX
# BTC-AVAX
# BTC-IMX
# BTC-RNDR
# BTC-RLY
# KRW-T
# BTC-T
# KRW-CELO
# BTC-RAD
# BTC-AGLD
# BTC-API3
# BTC-ARPA
# BTC-ENS

# %%
for i in range(len(tickers)):
    print(tickers[i])
# Out:
# KRW-BTC
# KRW-ETH
# BTC-ETH
# BTC-LTC
# BTC-XRP
# BTC-ETC
# BTC-OMG
# BTC-CVC
# BTC-DGB
# BTC-SC
# BTC-SNT
# BTC-WAVES
# BTC-NMR
# BTC-XEM
# BTC-QTUM
# BTC-BAT
# BTC-LSK
# BTC-STEEM
# BTC-DOGE
# BTC-BNT
# BTC-XLM
# BTC-ARDR
# BTC-ARK
# BTC-STORJ
# BTC-GRS
# BTC-REP
# BTC-RLC
# USDT-BTC
# USDT-ETH
# USDT-LTC
# USDT-XRP
# USDT-ETC
# KRW-NEO
# KRW-MTL
# KRW-LTC
# KRW-XRP
# KRW-ETC
# KRW-OMG
# KRW-SNT
# KRW-WAVES
# KRW-XEM
# KRW-QTUM
# KRW-LSK
# KRW-STEEM
# KRW-XLM
# KRW-ARDR
# KRW-ARK
# KRW-STORJ
# KRW-GRS
# KRW-REP
# KRW-ADA
# BTC-ADA
# BTC-MANA
# USDT-OMG
# KRW-SBD
# BTC-SBD
# KRW-POWR
# BTC-POWR
# KRW-BTG
# USDT-ADA
# BTC-DNT
# BTC-ZRX
# BTC-TRX
# BTC-TUSD
# BTC-LRC
# KRW-ICX
# KRW-EOS
# USDT-TUSD
# KRW-TRX
# BTC-POLY
# USDT-SC
# USDT-TRX
# KRW-SC
# KRW-ONT
# KRW-ZIL
# KRW-POLY
# KRW-ZRX
# KRW-LOOM
# BTC-BCH
# USDT-BCH
# KRW-BCH
# BTC-MFT
# BTC-LOOM
# KRW-BAT
# KRW-IOST
# BTC-RFR
# KRW-RFR
# USDT-DGB
# KRW-CVC
# KRW-IQ
# KRW-IOTA
# BTC-RVN
# BTC-GO
# BTC-UPP
# BTC-ENJ
# KRW-MFT
# KRW-ONG
# KRW-GAS
# BTC-MTL
# KRW-UPP
# KRW-ELF
# USDT-DOGE
# USDT-ZRX
# USDT-RVN
# USDT-BAT
# KRW-KNC
# BTC-MOC
# BTC-ZIL
# KRW-BSV
# BTC-BSV
# BTC-IOST
# KRW-THETA
# BTC-DENT
# KRW-QKC
# BTC-ELF
# KRW-BTT
# BTC-IOTX
# BTC-SOLVE
# BTC-NKN
# BTC-META
# KRW-MOC
# BTC-ANKR
# BTC-CRO
# KRW-ENJ
# KRW-TFUEL
# KRW-MANA
# KRW-ANKR
# BTC-ORBS
# BTC-AERGO
# KRW-AERGO
# KRW-ATOM
# KRW-TT
# KRW-CRE
# BTC-ATOM
# BTC-STPT
# KRW-MBL
# BTC-EOS
# BTC-LUNA
# BTC-DAI
# BTC-MKR
# BTC-BORA
# KRW-WAXP
# BTC-WAXP
# KRW-HBAR
# KRW-MED
# BTC-MED
# BTC-MLK
# KRW-MLK
# KRW-STPT
# BTC-VET
# KRW-ORBS
# BTC-CHZ
# KRW-VET
# BTC-FX
# BTC-OGN
# KRW-CHZ
# BTC-XTZ
# BTC-HIVE
# BTC-HBD
# BTC-OBSR
# BTC-DKA
# KRW-STMX
# BTC-STMX
# BTC-AHT
# BTC-PCI
# KRW-DKA
# BTC-LINK
# KRW-HIVE
# KRW-KAVA
# BTC-KAVA
# KRW-AHT
# KRW-LINK
# KRW-XTZ
# KRW-BORA
# BTC-JST
# BTC-CHR
# BTC-DAD
# BTC-TON
# KRW-JST
# BTC-CTSI
# BTC-DOT
# KRW-CRO
# BTC-COMP
# BTC-SXP
# BTC-HUNT
# KRW-TON
# BTC-ONIT
# BTC-CRV
# BTC-ALGO
# BTC-RSR
# KRW-SXP
# BTC-OXT
# BTC-PLA
# KRW-HUNT
# BTC-MARO
# BTC-SAND
# BTC-SUN
# KRW-PLA
# KRW-DOT
# BTC-SRM
# BTC-QTCON
# BTC-MVL
# KRW-SRM
# KRW-MVL
# BTC-REI
# BTC-AQT
# BTC-AXS
# BTC-STRAX
# KRW-STRAX
# KRW-AQT
# BTC-GLM
# KRW-GLM
# BTC-FCT2
# BTC-SSX
# KRW-SSX
# KRW-META
# KRW-FCT2
# BTC-FIL
# BTC-UNI
# BTC-BASIC
# BTC-INJ
# BTC-PROM
# BTC-VAL
# BTC-PSG
# BTC-JUV
# BTC-CBK
# BTC-FOR
# KRW-CBK
# BTC-BFC
# BTC-LINA
# BTC-HUM
# BTC-CELO
# KRW-SAND
# KRW-HUM
# BTC-IQ
# BTC-STX
# KRW-DOGE
# BTC-NEAR
# BTC-AUCTION
# BTC-DAWN
# BTC-FLOW
# BTC-STRK
# KRW-STRK
# BTC-PUNDIX
# KRW-PUNDIX
# KRW-FLOW
# KRW-DAWN
# KRW-AXS
# KRW-STX
# BTC-GRT
# BTC-SNX
# BTC-USDP
# KRW-XEC
# KRW-SOL
# BTC-SOL
# KRW-MATIC
# BTC-MATIC
# KRW-NU
# BTC-NU
# KRW-AAVE
# KRW-1INCH
# BTC-AAVE
# BTC-1INCH
# BTC-MASK
# KRW-ALGO
# BTC-AUDIO
# KRW-NEAR
# BTC-YGG
# BTC-GTC
# BTC-OCEAN
# BTC-CTC
# BTC-LPT
# KRW-WEMIX
# BTC-WEMIX
# KRW-AVAX
# BTC-AVAX
# BTC-IMX
# BTC-RNDR
# BTC-RLY
# KRW-T
# BTC-T
# KRW-CELO
# BTC-RAD
# BTC-AGLD
# BTC-API3
# BTC-ARPA
# BTC-ENS

# %% [markdown]
# ### 현재가 조회

# %%
pyupbit.get_current_price('KRW-BTC')
# Out:
# 48835000.0

# %%
pyupbit.get_current_price('KRW-ETH')
# Out:
# 3595000.0

# %%
pyupbit.get_current_price('BTC-ETH')
# Out:
# 0.07353068

# %%
# 주문 : 초당 8회, 분당 200회
# 주문 이외 : 초당 30회, 분당 900회

# %%
import time

for t in tickers:
    price = pyupbit.get_current_price(t)
    print(price)
    time.sleep(0.2)
# Out:
# 48805000.0
# 3596000.0
# 0.07353068
# 0.00264
# 1.618e-05
# 0.00071492
# 9.723e-05
# 6.83e-06
# 5.1e-07
# 2.1e-07
# 1.4e-06
# 0.00032295
# 0.000603
# 2.3e-06
# 0.00014148
# 1.503e-05
# 4.569e-05
# 9.57e-06
# 3.45e-06
# 5.24e-05
# 4.51e-06
# 4.8e-06
# 2.094e-05
# 2.268e-05
# 1.515e-05
# 0.00030136
# 3.963e-05
# 37936.875
# 2809.14707159
# 102.48981722
# 0.61437533
# 28.0220115
# 22850.0
# 2435.0
# 129000.0
# 788.0
# 34840.0
# 4865.0
# 68.7
# 15510.0
# 114.0
# 7015.0
# 2250.0
# 465.0
# 222.0
# 229.0
# 1000.0
# 1140.0
# 743.0
# 14840.0
# 1000.0
# 2.054e-05
# 3.906e-05
# 3.70654773
# 4620.0
# 9.458e-05
# 538.0
# 1.098e-05
# 36010.0
# 0.80531936
# 2.51e-06
# 1.843e-05
# 1.89e-06
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12544/3962267110.py in <module>
#       4     price = pyupbit.get_current_price(t)
#       5     print(price)
# ----> 6     time.sleep(0.2)
#
# KeyboardInterrupt:

# %%
import time

for t in tickers[:10]:
    price = pyupbit.get_current_price(t)
    
    if t[:3] == 'KRW':
        print(t, price)
        
    else:
        pass
    
    time.sleep(0.2)
# Out:
# KRW-BTC 48795000.0
# KRW-ETH 3592000.0

# %%
data = pyupbit.get_current_price(['KRW-BTC', 'BTC-ETH'])
data

for d in data.items():
    print(d)
# Out:
# ('KRW-BTC', 48830000.0)
# ('BTC-ETH', 0.07353068)

# %% [markdown]
# ### 분봉/일봉/주봉/월봉 조회

# %%
df = pyupbit.get_ohlcv('KRW-BTC', interval='day', count=30)
df
# Out:
#                            open        high         low       close  \
# 2022-04-05 09:00:00  57069000.0  57645000.0  56070000.0  56155000.0
# 2022-04-06 09:00:00  56195000.0  56323000.0  53034000.0  53072000.0
# 2022-04-07 09:00:00  53072000.0  54340000.0  52754000.0  53814000.0
# 2022-04-08 09:00:00  53813000.0  54700000.0  52798000.0  52934000.0
# 2022-04-09 09:00:00  52934000.0  53355000.0  52754000.0  53258000.0
# 2022-04-10 09:00:00  53295000.0  53950000.0  52462000.0  52819000.0
# 2022-04-11 09:00:00  52799000.0  53060000.0  50010000.0  50050000.0
# 2022-04-12 09:00:00  50050000.0  51195000.0  49608000.0  50577000.0
# 2022-04-13 09:00:00  50577000.0  51947000.0  49936000.0  51700000.0
# 2022-04-14 09:00:00  51645000.0  51942000.0  50000000.0  50245000.0
# 2022-04-15 09:00:00  50275000.0  51286000.0  50079000.0  50850000.0
# 2022-04-16 09:00:00  50807000.0  51100000.0  50251000.0  50567000.0
# 2022-04-17 09:00:00  50567000.0  50698000.0  49851000.0  49962000.0
# 2022-04-18 09:00:00  49962000.0  51290000.0  48626000.0  50839000.0
# 2022-04-19 09:00:00  50768000.0  51904000.0  50550000.0  51458000.0
# 2022-04-20 09:00:00  51459000.0  52326000.0  51015000.0  51388000.0
# 2022-04-21 09:00:00  51436000.0  53075000.0  50250000.0  50805000.0
# 2022-04-22 09:00:00  50805000.0  51000000.0  49526000.0  49937000.0
# 2022-04-23 09:00:00  49937000.0  50290000.0  49466000.0  49742000.0
# 2022-04-24 09:00:00  49723000.0  50211000.0  49300000.0  49620000.0
# 2022-04-25 09:00:00  49620000.0  50993000.0  48600000.0  50614000.0
# 2022-04-26 09:00:00  50614000.0  51193000.0  48300000.0  48777000.0
# 2022-04-27 09:00:00  48718000.0  50100000.0  48568000.0  49954000.0
# 2022-04-28 09:00:00  49954000.0  51299000.0  49666000.0  50580000.0
# 2022-04-29 09:00:00  50580000.0  50829000.0  49412000.0  49731000.0
# 2022-04-30 09:00:00  49731000.0  49953000.0  49243000.0  49283000.0
# 2022-05-01 09:00:00  49283000.0  49620000.0  48500000.0  49383000.0
# 2022-05-02 09:00:00  49383000.0  50210000.0  49110000.0  49520000.0
# 2022-05-03 09:00:00  49501000.0  49678000.0  48638000.0  48777000.0
# 2022-05-04 09:00:00  48772000.0  48999000.0  48722000.0  48853000.0
#
#                           volume         value
# 2022-04-05 09:00:00  4627.208651  2.629691e+11
# 2022-04-06 09:00:00  6776.518826  3.716776e+11
# 2022-04-07 09:00:00  5354.289371  2.871157e+11
# 2020-10-04 09:00:00    869.827279  1.079626e+10
# 2020-10-05 09:00:00   1578.027830  1.965762e+10
# 2020-10-06 09:00:00   1745.875329  2.175526e+10
# 2020-10-07 09:00:00   1357.358223  1.679513e+10
#
# [200 rows x 6 columns]

# %%
import pandas as pd

last = '20201008'
last = pd.to_datetime(last)
last = last + pd.Timedelta(days=1)

df = pyupbit.get_ohlcv('KRW-BTC', to=last)
df
# Out:
#                            open        high         low       close  \
# 2020-03-23 09:00:00   7379000.0   8189000.0   7219000.0   8047000.0
# 2020-03-24 09:00:00   8047000.0   8412000.0   7892000.0   8367000.0
# 2020-03-25 09:00:00   8362000.0   8538000.0   8080000.0   8271000.0
# 2020-03-26 09:00:00   8276000.0   8344000.0   8091000.0   8272000.0
# 2020-03-27 09:00:00   8281000.0   8365000.0   7820000.0   7880000.0
# ...                         ...         ...         ...         ...
# 2020-10-04 09:00:00  12393000.0  12496000.0  12348000.0  12447000.0
# 2020-10-05 09:00:00  12446000.0  12545000.0  12385000.0  12536000.0
# 2020-10-06 09:00:00  12536000.0  12600000.0  12330000.0  12418000.0
# 2020-10-07 09:00:00  12408000.0  12435000.0  12337000.0  12423000.0
# 2020-10-08 09:00:00  12422000.0  12680000.0  12280000.0  12582000.0
#
#                            volume         value
# 2020-03-23 09:00:00  16867.529534  1.305781e+11
# 2020-03-24 09:00:00  15158.039589  1.244216e+11
# 2020-03-25 09:00:00  12629.118008  1.043876e+11
# 2020-03-26 09:00:00   6160.813270  5.057246e+10
# 2020-03-27 09:00:00   6749.553055  5.514416e+10
# ...                           ...           ...
# 2020-10-04 09:00:00    869.827279  1.079626e+10
# 2020-10-05 09:00:00   1578.027830  1.965762e+10
# 2020-10-06 09:00:00   1745.875329  2.175526e+10
# 2020-10-07 09:00:00   1357.358223  1.679513e+10
# 2020-10-08 09:00:00   2422.119262  3.014610e+10
#
# [200 rows x 6 columns]

# %%
start = '20190101'
last = '20210101'
last = pd.to_datetime(last) + pd.Timedelta(days = 1)

while True:
    df = pyupbit.get_ohlcv('KRW-BTC', to=last)
    last = df.index[0]
    
    print(df.head(1))
    
    if start in df.index:
        break
    
    time.sleep(0.1)
# Out:
#                            open        high         low       close  \
# 2020-06-16 09:00:00  11339000.0  11492000.0  11267000.0  11453000.0
#
#                           volume         value
# 2020-06-16 09:00:00  3026.568243  3.450289e+10
#                           open       high        low      close     volume  \
# 2019-11-29 09:00:00  8672000.0  9200000.0  8658000.0  9037000.0  4210.8005
#
#                             value
# 2019-11-29 09:00:00  3.763841e+10
#                           open       high        low      close        volume  \
# 2019-05-13 09:00:00  8166000.0  9518000.0  8064000.0  9230000.0  26618.706357
#
#                             value
# 2019-05-13 09:00:00  2.356440e+11
#                           open       high        low      close       volume  \
# 2018-10-25 09:00:00  7296000.0  7300000.0  7229000.0  7272000.0  2934.436376
#
#                             value
# 2018-10-25 09:00:00  2.130565e+10

# %%
def ohlcv(ticker, start, last):
    last = pd.to_datetime(last)
    last = last + pd.Timedelta(days=1)
    
    dfs = []
    
    while True:
        df = pyupbit.get_ohlcv(ticker, to=last)
        last = df.index[0]
        
        dfs.append(df)
        
        if start in df.index:
            break
        time.sleep(0.2)
        
    result = pd.concat(dfs).sort_index()
    return result.loc[start:]

# %%
start = '20200101'
end = '20211001'

ohlcv('BTC-LTC', start, end)
# Out:
#                          open      high       low     close      volume  \
# 2020-01-01 09:00:00  0.005400  0.005400  0.005400  0.005400    0.477830
# 2020-01-03 09:00:00  0.005400  0.005401  0.005400  0.005401   25.404035
# 2020-01-05 09:00:00  0.005401  0.006000  0.005401  0.006000   32.330073
# 2020-01-06 09:00:00  0.006000  0.006000  0.006000  0.006000   14.091164
# 2020-01-07 09:00:00  0.006000  0.006000  0.006000  0.006000    2.125082
# ...                       ...       ...       ...       ...         ...
# 2021-09-27 09:00:00  0.003476  0.003534  0.003422  0.003422   77.210812
# 2021-09-28 09:00:00  0.003417  0.003505  0.003412  0.003429  224.073112
# 2021-09-29 09:00:00  0.003445  0.003547  0.003412  0.003472  101.271949
# 2021-09-30 09:00:00  0.003472  0.003560  0.003460  0.003479   81.567286
# 2021-10-01 09:00:00  0.003497  0.003562  0.003400  0.003433  148.220338
#
#                         value
# 2020-01-01 09:00:00  0.002580
# 2020-01-03 09:00:00  0.137188
# 2020-01-05 09:00:00  0.192652
# 2020-01-06 09:00:00  0.084545
# 2020-01-07 09:00:00  0.012750
# ...                       ...
# 2021-09-27 09:00:00  0.268239
# 2021-09-28 09:00:00  0.771242
# 2021-09-29 09:00:00  0.351531
# 2021-09-30 09:00:00  0.284006
# 2021-10-01 09:00:00  0.517757
#
# [612 rows x 6 columns]

# %% [markdown]
# ### 호가정보

# %%
r = pyupbit.get_orderbook('KRW-BTC')
r
# Out:
# {'market': 'KRW-BTC',
#  'timestamp': 1651632612225,
#  'total_ask_size': 10.431715899999997,
#  'total_bid_size': 1.34070045,
#  'orderbook_units': [{'ask_price': 48846000.0,
#    'bid_price': 48845000.0,
#    'ask_size': 0.01183872,
#    'bid_size': 0.0057882},
#   {'ask_price': 48848000.0,
#    'bid_price': 48844000.0,
#    'ask_size': 0.55962673,
#    'bid_size': 0.00102354},
#   {'ask_price': 48850000.0,
#    'bid_price': 48843000.0,
#    'ask_size': 0.04252386,
#    'bid_size': 0.00122329},
#   {'ask_price': 48851000.0,
#    'bid_price': 48842000.0,
#    'ask_size': 6.48249701,
#    'bid_size': 0.0150137},
#   {'ask_price': 48875000.0,
#    'bid_price': 48841000.0,
#    'ask_size': 0.08361149,
#    'bid_size': 0.00225216},
#   {'ask_price': 48889000.0,
#    'bid_price': 48840000.0,
#    'ask_size': 0.17750568,
#    'bid_size': 0.04871011},
#   {'ask_price': 48890000.0,
#    'bid_price': 48839000.0,
#    'ask_size': 0.68242117,
#    'bid_size': 0.01185743},
#   {'ask_price': 48891000.0,
#    'bid_price': 48838000.0,
#    'ask_size': 0.3404,
#    'bid_size': 0.20834343},
#   {'ask_price': 48895000.0,
#    'bid_price': 48837000.0,
#    'ask_size': 0.19814299,
#    'bid_size': 0.49351128},
#   {'ask_price': 48899000.0,
#    'bid_price': 48835000.0,
#    'ask_size': 0.14866807,
#    'bid_size': 0.00549977},
#   {'ask_price': 48900000.0,
#    'bid_price': 48834000.0,
#    'ask_size': 0.96020514,
#    'bid_size': 0.03432209},
#   {'ask_price': 48902000.0,
#    'bid_price': 48833000.0,
#    'ask_size': 0.3761,
#    'bid_size': 0.05759646},
#   {'ask_price': 48910000.0,
#    'bid_price': 48832000.0,
#    'ask_size': 0.03014792,
#    'bid_size': 0.17994904},
#   {'ask_price': 48914000.0,
#    'bid_price': 48831000.0,
#    'ask_size': 0.3378,
#    'bid_size': 0.07816476},
#   {'ask_price': 48922000.0,
#    'bid_price': 48830000.0,
#    'ask_size': 0.00022712,
#    'bid_size': 0.19744519}]}

# %%
r.keys()
# Out:
# dict_keys(['market', 'timestamp', 'total_ask_size', 'total_bid_size', 'orderbook_units'])

# %%
r['market']
# Out:
# 'KRW-BTC'

# %% [markdown]
# ### 타임스탬프

# %%
r['timestamp']  # 19700101부터 현재 시점까지의 milli seconds
# Out:
# 1651632612225

# %%
r['timestamp'] / 1000 / 60 / 60 / 24 / 365
# Out:
# 52.372926567256464

# %%
r['orderbook_units']
# Out:
# [{'ask_price': 48846000.0,
#   'bid_price': 48845000.0,
#   'ask_size': 0.01183872,
#   'bid_size': 0.0057882},
#  {'ask_price': 48848000.0,
#   'bid_price': 48844000.0,
#   'ask_size': 0.55962673,
#   'bid_size': 0.00102354},
#  {'ask_price': 48850000.0,
#   'bid_price': 48843000.0,
#   'ask_size': 0.04252386,
#   'bid_size': 0.00122329},
#  {'ask_price': 48851000.0,
#   'bid_price': 48842000.0,
#   'ask_size': 6.48249701,
#   'bid_size': 0.0150137},
#  {'ask_price': 48875000.0,
#   'bid_price': 48841000.0,
#   'ask_size': 0.08361149,
#   'bid_size': 0.00225216},
#  {'ask_price': 48889000.0,
#   'bid_price': 48840000.0,
#   'ask_size': 0.17750568,
#   'bid_size': 0.04871011},
#  {'ask_price': 48890000.0,
#   'bid_price': 48839000.0,
#   'ask_size': 0.68242117,
#   'bid_size': 0.01185743},
#  {'ask_price': 48891000.0,
#   'bid_price': 48838000.0,
#   'ask_size': 0.3404,
#   'bid_size': 0.20834343},
#  {'ask_price': 48895000.0,
#   'bid_price': 48837000.0,
#   'ask_size': 0.19814299,
#   'bid_size': 0.49351128},
#  {'ask_price': 48899000.0,
#   'bid_price': 48835000.0,
#   'ask_size': 0.14866807,
#   'bid_size': 0.00549977},
#  {'ask_price': 48900000.0,
#   'bid_price': 48834000.0,
#   'ask_size': 0.96020514,
#   'bid_size': 0.03432209},
#  {'ask_price': 48902000.0,
#   'bid_price': 48833000.0,
#   'ask_size': 0.3761,
#   'bid_size': 0.05759646},
#  {'ask_price': 48910000.0,
#   'bid_price': 48832000.0,
#   'ask_size': 0.03014792,
#   'bid_size': 0.17994904},
#  {'ask_price': 48914000.0,
#   'bid_price': 48831000.0,
#   'ask_size': 0.3378,
#   'bid_size': 0.07816476},
#  {'ask_price': 48922000.0,
#   'bid_price': 48830000.0,
#   'ask_size': 0.00022712,
#   'bid_size': 0.19744519}]

# %%
for v in r['orderbook_units']:
    print(v)
# Out:
# {'ask_price': 48846000.0, 'bid_price': 48845000.0, 'ask_size': 0.01183872, 'bid_size': 0.0057882}
# {'ask_price': 48848000.0, 'bid_price': 48844000.0, 'ask_size': 0.55962673, 'bid_size': 0.00102354}
# {'ask_price': 48850000.0, 'bid_price': 48843000.0, 'ask_size': 0.04252386, 'bid_size': 0.00122329}
# {'ask_price': 48851000.0, 'bid_price': 48842000.0, 'ask_size': 6.48249701, 'bid_size': 0.0150137}
# {'ask_price': 48875000.0, 'bid_price': 48841000.0, 'ask_size': 0.08361149, 'bid_size': 0.00225216}
# {'ask_price': 48889000.0, 'bid_price': 48840000.0, 'ask_size': 0.17750568, 'bid_size': 0.04871011}
# {'ask_price': 48890000.0, 'bid_price': 48839000.0, 'ask_size': 0.68242117, 'bid_size': 0.01185743}
# {'ask_price': 48891000.0, 'bid_price': 48838000.0, 'ask_size': 0.3404, 'bid_size': 0.20834343}
# {'ask_price': 48895000.0, 'bid_price': 48837000.0, 'ask_size': 0.19814299, 'bid_size': 0.49351128}
# {'ask_price': 48899000.0, 'bid_price': 48835000.0, 'ask_size': 0.14866807, 'bid_size': 0.00549977}
# {'ask_price': 48900000.0, 'bid_price': 48834000.0, 'ask_size': 0.96020514, 'bid_size': 0.03432209}
# {'ask_price': 48902000.0, 'bid_price': 48833000.0, 'ask_size': 0.3761, 'bid_size': 0.05759646}
# {'ask_price': 48910000.0, 'bid_price': 48832000.0, 'ask_size': 0.03014792, 'bid_size': 0.17994904}
# {'ask_price': 48914000.0, 'bid_price': 48831000.0, 'ask_size': 0.3378, 'bid_size': 0.07816476}
# {'ask_price': 48922000.0, 'bid_price': 48830000.0, 'ask_size': 0.00022712, 'bid_size': 0.19744519}

# %%
for v in r['orderbook_units'][::-1]:
    print(v['ask_price'], v['ask_size'])
# Out:
# 48922000.0 0.00022712
# 48914000.0 0.3378
# 48910000.0 0.03014792
# 48902000.0 0.3761
# 48900000.0 0.96020514
# 48899000.0 0.14866807
# 48895000.0 0.19814299
# 48891000.0 0.3404
# 48890000.0 0.68242117
# 48889000.0 0.17750568
# 48875000.0 0.08361149
# 48851000.0 6.48249701
# 48850000.0 0.04252386
# 48848000.0 0.55962673
# 48846000.0 0.01183872

# %%
for v in r['orderbook_units'][::-1]:
    print(v['bid_price'], v['bid_size'])
# Out:
# 48830000.0 0.19744519
# 48831000.0 0.07816476
# 48832000.0 0.17994904
# 48833000.0 0.05759646
# 48834000.0 0.03432209
# 48835000.0 0.00549977
# 48837000.0 0.49351128
# 48838000.0 0.20834343
# 48839000.0 0.01185743
# 48840000.0 0.04871011
# 48841000.0 0.00225216
# 48842000.0 0.0150137
# 48843000.0 0.00122329
# 48844000.0 0.00102354
# 48845000.0 0.0057882

# %% [markdown]
# ### bithumb api

# %%
# 1초 당 최대 135회

# %%
# !pip install -U pybithumb

# %%
import pybithumb

# %%
tickers = pybithumb.get_tickers()

# %%
len(tickers)
# Out:
# 201

# %%
for ticker in tickers:
    price = pybithumb.get_current_price(ticker)
    print(ticker, price)
    
    time.sleep(0.2)
# Out:
# BTC 48754000.0
# ETH 3589000.0
# LTC 128600.0
# ETC 34810.0
# XRP 789.1
# BCH 363700.0
# QTUM 7005.0
# BTG 35870.0
# EOS 2679.0
# ICX 834.3
# TRX 91.16
# ELF 344.0
# OMG 4857.0
# KNC 4316.0
# GLM 437.1
# ZIL 88.37
# WAXP 270.1
# POWR 536.3
# LRC 941.1
# STEEM 470.6
# STRAX 1145.0
# ZRX 921.8
# REP 14820.0
# XEM 112.7
# SNT 69.72
# ADA 1002.0
# CTXC 271.7
# BAT 772.0
# THETA 2992.0
# LOOM 98.6
# WAVES 15700.0
# LINK 14390.0
# ENJ 1387.0
# VET 61.32
# MTL 2398.0
# IOST 28.2
# TMTG 2.96
# QKC 21.58
# ATOLO 37.7
# AMO 2.374
# BSV 93050.0
# ORBS 84.66
# TFUEL 168.0
# VALOR 523.0
# CON 31.34
# ANKR 79.24
# MIX 9.713
# CRO 376.4
# FX 580.1
# CHR 455.9
# MBL 10.32
# MXC 132.7
# FCT2 141.6
# TRV 18.57
# DAD 145.5
# WOM 108.5
# SOC 11.26
# BOA 101.7
# MEV 24.2
# SXP 1337.0
# COS 16.4
# APIX 52.81
# EL 7.095
# BASIC 4.71
# HIVE 997.0
# XPR 11.12
# VRA 17.94
# FIT 2.049
# EGG 37.88
# BORA 799.5
# ARPA 73.79
# CTC 979.8
# APM 40.01
# CKB 11.46
# AERGO 260.7
# ANW 30.98
# CENNZ 116.2
# EVZ 63.1
# CYCLUB 12.85
# SRM 2363.0
# QTCON 6.765
# UNI 8935.0
# YFI 22414000.0
# UMA 6915.0
# AAVE 184100.0
# COMP 134900.0
# REN 354.7
# BAL 16290.0
# RSR 11.29
# NMR 29550.0
# RLC 1945.0
# UOS 912.7
# SAND 2794.0
# GOM2 46.09
# RINGX 27.04
# BEL 856.7
# OBSR 4.031
# ORC 297.0
# POLA 92.04
# AWO 52.07
# ADP 36.23
# DVI 393.9
# GHX 60.73
# MIR 1478.0
# MVC 15.03
# BLY 23.13
# WOZX 138.0
# ANV 565.2
# GRT 409.5
# MM 439.4
# BIOT 37.48
# XNO 62.93
# SNX 6030.0
# SOFI 252.6
# COLA 162.7
# OXT 262.3
# LINA 23.6
# MAP 25.77
# AQT 2929.0
# PLA 946.0
# WIKEN 18.06
# CTSI 355.3
# MANA 1920.0
# LPT 28580.0
# MKR 1824000.0
# SUSHI 3058.0
# ASM 50.97
# PUNDIX 982.8
# CELR 43.25
# CWD 93.46
# ARW 1123.0
# FRONT 519.7
# RLY 177.0
# OCEAN 527.5
# BFC 160.0
# ALICE 6440.0
# OGN 580.7
# COTI 252.9
# CAKE 9500.0
# BNT 2536.0
# XVS 10100.0
# SWAP 752.5
# CHZ 232.4
# AXS 37630.0
# DAO 4294.0
# SIX 197.0
# DAI 1284.0
# MATIC 1398.0
# WOO 452.0
# ACH 30.53
# VELO 56.98
# XLM 223.1
# VSYS 10.25
# IPX 50.03
# WICC 148.9
# ONT 587.2
# LUNA 106300.0
# AION 92.21
# META 85.23
# KLAY 886.5
# ONG 786.9
# ALGO 885.3
# JST 78.33
# XTZ 3238.0
# MLK 913.5
# WEMIX 3125.0
# DOT 19200.0
# ATOM 23010.0
# SSX 53.13
# TEMCO 5.84
# HIBS 2.27
# BURGER 1393.0
# DOGE 167.5
# KSM 168100.0
# CTK 1339.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12544/3893786347.py in <module>
#       1 for ticker in tickers:
# ----> 2     price = pybithumb.get_current_price(ticker)
#       3     print(ticker, price)
#       4
#       5     time.sleep(0.2)
#
# ~\anaconda3\lib\site-packages\pybithumb\__init__.py in get_current_price(order_currency, payment_currency)
#      15
#      16 def get_current_price(order_currency, payment_currency="KRW"):
# ---> 17     return Bithumb.get_current_price(order_currency, payment_currency)
#      18
#      19
#
# ~\anaconda3\lib\site-packages\pybithumb\client.py in get_current_price(order_currency, payment_currency)
#      97         resp = None
#      98         try:
# ---> 99             resp = PublicApi.ticker(order_currency, payment_currency)
#     100             if order_currency != "ALL":
#     101                 return float(resp['data']['closing_price'])
#
# ~\anaconda3\lib\site-packages\pybithumb\core.py in ticker(order_currency, payment_currency)
#      13     def ticker(order_currency, payment_currency="KRW"):
#      14         uri = "/public/ticker/{}_{}".format(order_currency, payment_currency)
# ---> 15         return BithumbHttp().get(uri)
#      16
#      17     @staticmethod
#
# ~\anaconda3\lib\site-packages\pybithumb\core.py in get(self, path, timeout, **kwargs)
#     110         try:
#     111             uri = self.base_url + path
# --> 112             return self.session.get(url=uri, params=kwargs, timeout=timeout).\
#     113                 json()
#     114         except Exception as x:
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1369         try:
#    1370             try:
# -> 1371                 response.begin()
#    1372             except ConnectionError:
#    1373                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
r = pybithumb.get_orderbook('BTC')
r
# Out:
# {'timestamp': '1651633766648',
#  'payment_currency': 'KRW',
#  'order_currency': 'BTC',
#  'bids': [{'price': 48730000.0, 'quantity': 0.0001},
#   {'price': 48722000.0, 'quantity': 0.1113},
#   {'price': 48720000.0, 'quantity': 0.0004},
#   {'price': 48719000.0, 'quantity': 0.4094},
#   {'price': 48718000.0, 'quantity': 0.2693}],
#  'asks': [{'price': 48754000.0, 'quantity': 0.2851},
#   {'price': 48756000.0, 'quantity': 0.0321},
#   {'price': 48759000.0, 'quantity': 0.3609},
#   {'price': 48760000.0, 'quantity': 0.0118},
#   {'price': 48761000.0, 'quantity': 0.63548871}]}

# %%
r['bids']
# Out:
# [{'price': 48730000.0, 'quantity': 0.0001},
#  {'price': 48722000.0, 'quantity': 0.1113},
#  {'price': 48720000.0, 'quantity': 0.0004},
#  {'price': 48719000.0, 'quantity': 0.4094},
#  {'price': 48718000.0, 'quantity': 0.2693}]

# %%
r['asks']
# Out:
# [{'price': 48754000.0, 'quantity': 0.2851},
#  {'price': 48756000.0, 'quantity': 0.0321},
#  {'price': 48759000.0, 'quantity': 0.3609},
#  {'price': 48760000.0, 'quantity': 0.0118},
#  {'price': 48761000.0, 'quantity': 0.63548871}]

# %%
r = pybithumb.get_orderbook('BTC', limit=30)

# %%
for o in r['asks'][::-1]:
    print(o)
# Out:
# {'price': 48903000.0, 'quantity': 0.0071}
# {'price': 48902000.0, 'quantity': 0.1}
# {'price': 48900000.0, 'quantity': 0.0107}
# {'price': 48893000.0, 'quantity': 0.04}
# {'price': 48867000.0, 'quantity': 0.286}
# {'price': 48866000.0, 'quantity': 0.1996}
# {'price': 48860000.0, 'quantity': 0.6}
# {'price': 48854000.0, 'quantity': 0.6}
# {'price': 48851000.0, 'quantity': 0.0124}
# {'price': 48850000.0, 'quantity': 8.3198}
# {'price': 48847000.0, 'quantity': 1.683}
# {'price': 48832000.0, 'quantity': 1.33}
# {'price': 48830000.0, 'quantity': 0.153}
# {'price': 48824000.0, 'quantity': 0.6}
# {'price': 48815000.0, 'quantity': 0.0615}
# {'price': 48807000.0, 'quantity': 0.6}
# {'price': 48805000.0, 'quantity': 0.057}
# {'price': 48802000.0, 'quantity': 0.0224}
# {'price': 48801000.0, 'quantity': 0.0559}
# {'price': 48798000.0, 'quantity': 0.055}
# {'price': 48796000.0, 'quantity': 0.0223}
# {'price': 48792000.0, 'quantity': 0.0383}
# {'price': 48789000.0, 'quantity': 0.1501}
# {'price': 48788000.0, 'quantity': 0.0351}
# {'price': 48787000.0, 'quantity': 0.3133}
# {'price': 48786000.0, 'quantity': 0.6}
# {'price': 48784000.0, 'quantity': 0.0508}
# {'price': 48783000.0, 'quantity': 0.0147}
# {'price': 48782000.0, 'quantity': 0.4204}
# {'price': 48781000.0, 'quantity': 0.0156}

# %%
r['bids']
# Out:
# [{'price': 48758000.0, 'quantity': 0.1413},
#  {'price': 48757000.0, 'quantity': 0.0775},
#  {'price': 48755000.0, 'quantity': 0.0335},
#  {'price': 48754000.0, 'quantity': 0.0562},
#  {'price': 48752000.0, 'quantity': 0.0177},
#  {'price': 48751000.0, 'quantity': 0.0043},
#  {'price': 48750000.0, 'quantity': 0.2747},
#  {'price': 48748000.0, 'quantity': 0.0309},
#  {'price': 48746000.0, 'quantity': 0.0144},
#  {'price': 48745000.0, 'quantity': 0.01},
#  {'price': 48744000.0, 'quantity': 0.0027},
#  {'price': 48743000.0, 'quantity': 0.4619},
#  {'price': 48742000.0, 'quantity': 0.2664},
#  {'price': 48740000.0, 'quantity': 0.0021},
#  {'price': 48739000.0, 'quantity': 0.0319},
#  {'price': 48735000.0, 'quantity': 0.3101},
#  {'price': 48733000.0, 'quantity': 0.0234},
#  {'price': 48732000.0, 'quantity': 0.1326},
#  {'price': 48726000.0, 'quantity': 0.0051},
#  {'price': 48725000.0, 'quantity': 0.2274},
#  {'price': 48724000.0, 'quantity': 0.1493},
#  {'price': 48722000.0, 'quantity': 0.2182},
#  {'price': 48720000.0, 'quantity': 0.0004},
#  {'price': 48719000.0, 'quantity': 0.6},
#  {'price': 48718000.0, 'quantity': 0.8693},
#  {'price': 48717000.0, 'quantity': 0.0201},
#  {'price': 48716000.0, 'quantity': 0.1},
#  {'price': 48715000.0, 'quantity': 0.0011},
#  {'price': 48713000.0, 'quantity': 0.0276},
#  {'price': 48710000.0, 'quantity': 0.0356}]
